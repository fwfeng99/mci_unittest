# %%
import os
import numpy as np
import pandas as pd

from astropy import units as u
from astropy.table import Table, Column, MaskedColumn
from astropy.time import Time, TimeDelta
from astropy.coordinates import SkyCoord, Distance, GCRS, CartesianRepresentation, match_coordinates_sky
from astropy.wcs import WCS
from astropy.io import fits, ascii
from astropy.stats import sigma_clip
from astroquery.vizier import Vizier
import itertools

from collections import Counter
import matplotlib.pyplot as plt

import pickle

# %% [markdown]
# ### 文件路径

# %%
log_path = "/home/fangwf/MCI_SimData/240119/L0/log_Data"
filename = "star_info_SN_1.fits"

hdu_info = fits.open(os.path.join(log_path, filename))
hdu_info[1].header
data = Table(hdu_info[1].data)

# %%
data.sort(keys=["phot_C1"], reverse=True)
# data_filter = data[:30]

# %%
# data_filter
data
# Out:
# <Table length=1476>
#         st_ra                st_dec       ...  st_magbp  st_magrp
#        float64              float64       ...  float64   float64
# --------------------- ------------------- ... --------- ---------
#   -0.0421548605724783 -0.0620446007688886 ... 18.851631 17.799767
#   -0.0350607245863903 -0.0602295277245039 ... 19.187937 18.088808
#   -0.0392748693400081 -0.0543449155356989 ... 19.368614 17.656769
# -0.040921376820786406 -0.0534149729855545 ... 18.923643 17.846592
#   -0.0330085575209097 -0.0573961414288459 ... 20.422438 19.438795
#   -0.0358498007389222  -0.059518607078324 ...  19.20387 18.231337
#   -0.0351638560178777 -0.0570766144748235 ... 20.267138 18.988693
#   -0.0369760829263804 -0.0585987407691617 ...   20.4057 19.001059
#   -0.0283488341313636 -0.0619602731417093 ... 20.640314 19.575008
# -0.040981499644200205  -0.061713093423137 ... 20.680843 18.521444
#                   ...                 ... ...       ...       ...
#   -0.0407494614347466  0.0561474103537529 ... 19.929996 18.667023
#  -0.04372597356121351  0.0573503445194649 ... 19.437166 18.450315
#   -0.0470210285500559  0.0594825185680066 ... 20.766329  18.80279
#   -0.0492911775422241  0.0600424142507124 ... 20.898106  18.91954
#    -0.035266146322445  0.0569724371680064 ... 21.123043 19.473719
# -0.038986978433394694  0.0572417344111383 ... 21.019808 19.615051
#   -0.0406167967201957  0.0513617304535686 ... 21.148216 19.159727
# -0.049038601162974094   0.056402895395193 ... 21.530478 19.545715
#   -0.0515244865262652  0.0617690758722445 ... 17.673443 16.947464
#   -0.0535987201565187  0.0616649087911727 ...  21.04807 20.038567

# %%
def write_ds9_region(filename, data, str_x, str_y):

    with open(filename, "w") as f:
        f.write(
            'global color=red dashlist=8 3 width=1 font="helvetica 10 normal roman" '
            "select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1"
            + "\n"
        )
        f.write("physical" + "\n")
        for i in range(len(data)):
            f.write(
                "circle("
                + str("%12.6f" % (data[str_x][i]))
                + ",  "
                + str("%12.6f" % (9232 - data[str_y][i]))
                + ","
                + str(15)
                + ")"
                + "\n"
            )



write_ds9_region("test.txt", data, "posX_C1", "posY_C1")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data.sort(keys=["phot_C1"], reverse=True)[:30]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# str("%12.6f" % (9232 - data[str_x][i]))
# Out:
# ' 7643.706087'
