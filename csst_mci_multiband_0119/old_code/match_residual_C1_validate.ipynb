# %%
import os
import numpy as np
import pandas as pd

from astropy import units as u
from astropy.table import Table, Column, MaskedColumn
from astropy.time import Time, TimeDelta
from astropy.coordinates import SkyCoord, Distance, GCRS, CartesianRepresentation, match_coordinates_sky
from astropy.wcs import WCS
from astropy.io import fits, ascii
from astroquery.vizier import Vizier
import itertools

from collections import Counter
import matplotlib.pyplot as plt

import pickle

# %% [markdown]
# ### 函数定义

# %%
def work_sext(
    image_path: str,
    config_path: str,
    out_path: str,
    flag_path: str,
    weight_path: str,
    out_para_path: str,
    filter_path: str,
):
    """
    Do astrometry by source-extractor.

    Do astrometry by source-extractor, the basic use of source-extractor is 'source-extractor  -c ' + fp_config + fp_image'

    Parameters
    ----------
    image_path : str
        The image fits to be processed, *.fits.
    config_path : str
        The config file of source-extractor, *.sex.
    out_path : str
        The name of the output catalog.
    out_para_path : str
        The parameters of the output catalog, *.param.
    filter_path : str
        The filter of the image, *.conv.

    Returns
    -------
    None

    Examples
    -------
    >>> work_sext(fp_img,fp_config_sext,fp_out_sext,fp_para_sext,fp_filter_sext)
    """
    fp_image = image_path
    fp_config = config_path
    fp_out = out_path
    fp_flg = flag_path
    fp_wht = weight_path
    fp_para = out_para_path
    fp_filter = filter_path

    cmd_sex = (
        "sex -c "
        + fp_config + " "
        + fp_image
        + " -CATALOG_NAME "
        + fp_out
        + " -FLAG_IMAGE "
        + fp_flg
        + " -WEIGHT_IMAGE "
        + fp_wht
        + " -PARAMETERS_NAME "
        + fp_para
        + " -FILTER_NAME "
        + fp_filter
    )

    os.system(cmd_sex)

def gaiadr3_query(
    ra: list,
    dec: list,
    rad: float = 1.0,
    maxmag: float = 25,
    maxsources: float = 1000000,
):
    """
    Acquire the Gaia DR3.

    This function uses astroquery.vizier to query Gaia DR3 catalog.

    Parameters
    ----------
    ra : list
        RA of center in degrees.
    dec : list
        Dec of center in degrees.
    rad : float
        Field radius in degrees.
    maxmag : float
        Upper limit magnitude.
    maxsources : float
        Maximum number of sources.

    Returns
    -------
    Table
        table of reference catalog.

    Examples
    --------
    >>> catalog = gaiadr3_query(ra, dec, rad, maxmag, maxsources)
    """

    vquery = Vizier(
        columns=["RA_ICRS", "DE_ICRS", "pmRA", "pmDE", "Plx", "RVDR2", "Gmag", "RV"],
        row_limit=maxsources,
        column_filters={"Gmag": ("<%f" % maxmag), "Plx": ">0"},
    )
    coord = SkyCoord(ra=ra, dec=dec, unit=u.deg, frame="icrs")
    r = vquery.query_region(coord, radius=rad * u.deg, catalog="I/355/gaiadr3")

    return r[0]

def ideal_cel_coord(xi, eta, ra_c, dec_c):
    ra_c = np.deg2rad(ra_c)
    dec_c = np.deg2rad(dec_c)

    ra = np.arctan(xi / (np.cos(dec_c) - eta * np.sin(dec_c))) + ra_c
    dec = np.arctan(
        (eta * np.cos(dec_c) + np.sin(dec_c))
        / (np.cos(dec_c) - eta * np.sin(dec_c))
        * np.cos(ra - ra_c)
    )
    ra = np.degrees(ra)
    dec = np.degrees(dec)

    return ra, dec

def cel_ideal_coord(ra, dec, ra_c, dec_c):

    ra = np.radians(ra)
    dec = np.radians(dec)
    ra_c = np.radians(ra_c)
    dec_c = np.radians(dec_c)

    xi = (np.cos(dec) * np.sin(ra - ra_c)) / (
        np.sin(dec_c) * np.sin(dec) + np.cos(dec_c) * np.cos(dec) * np.cos(ra - ra_c)
    )
    eta = (
        np.cos(dec_c) * np.sin(dec) - np.sin(dec_c) * np.cos(dec) * np.cos(ra - ra_c)
    ) / (np.sin(dec_c) * np.sin(dec) + np.cos(dec_c) * np.cos(dec) * np.cos(ra - ra_c))

    return xi, eta

def pos_side(ra_a, dec_a, ra_b, dec_b):
    ra_a_c = np.deg2rad(ra_a)
    dec_a_c = np.deg2rad(dec_a)
    ra_b_c = np.deg2rad(ra_b)
    dec_b_c = np.deg2rad(dec_b)

    a_vector = np.array([np.cos(dec_a_c) * np.cos(ra_a_c), np.cos(dec_a_c) * np.sin(ra_a_c), np.sin(dec_a_c)])
    b_vector = np.array([np.cos(dec_b_c) * np.cos(ra_b_c), np.cos(dec_b_c) * np.sin(ra_b_c), np.sin(dec_b_c)])
    return np.rad2deg(np.arccos(np.sum(a_vector * b_vector, axis=0)))


def cal_plate_model(X_x, X_y, Y_xi, Y_eta, cof):
    
    X_xy = []
    for i in range(0, cof + 1):
        for j in range(0, i + 1):
            X_xy.append(X_x ** (i - j) * X_y ** j)
    X_xy = np.array(X_xy).T
    
    A_CD1 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_xi
    A_CD2 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_eta

    A_CD = np.array([A_CD1, A_CD2])

    return A_CD

def use_plate_model(X_x, X_y, A_CD, cof):

    X_xy = []
    for i in range(0, cof + 1):
        for j in range(0, i + 1):
            X_xy.append(X_x ** (i - j) * X_y ** j)
    X_xy = np.array(X_xy).T

    xi_eta = A_CD @ X_xy.T * (np.pi / 180)
    xi_eta = A_CD @ X_xy.T

    return xi_eta

def cal_plate_model_mag(X_x, X_y, mag, Y_xi, Y_eta, cof, cof_mag):
    
    X_xy = []
    for i in range(0, cof + 1):
        for j in range(0, i + 1):
            X_xy.append(X_x ** (i - j) * X_y ** j)
    for k in range(1, cof_mag + 1):
        X_xy.append(mag ** k)
    # X_xy.append(mag * X_x)
    # X_xy.append(mag * X_y)
    # X_xy.append(mag * X_x ** 2)
    # X_xy.append(mag * X_x * X_y)
    # X_xy.append(mag * X_y ** 2)

    # X_xy.append(mag * X_x, mag * X_y, mag * X_x ** 2, mag * X_x * X_y, mag * X_y ** 2)

    X_xy = np.array(X_xy).T
    
    A_CD1 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_xi
    A_CD2 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_eta

    A_CD = np.array([A_CD1, A_CD2])

    return A_CD

def use_plate_model_mag(X_x, X_y, mag, A_CD, cof, cof_mag):

    X_xy = []
    for i in range(0, cof + 1):
        for j in range(0, i + 1):
            X_xy.append(X_x ** (i - j) * X_y ** j)
    for k in range(1, cof_mag + 1):
        X_xy.append(mag ** k)
    # X_xy.append(mag * X_x)
    # X_xy.append(mag * X_y)
    # X_xy.append(mag * X_x ** 2)
    # X_xy.append(mag * X_x * X_y)
    # X_xy.append(mag * X_y ** 2)
    # X_xy.append(mag * X_x, mag * X_y, mag * X_x ** 2, mag * X_x * X_y, mag * X_y ** 2)

    X_xy = np.array(X_xy).T

    xi_eta = A_CD @ X_xy.T * (np.pi / 180)
    xi_eta = A_CD @ X_xy.T

    return xi_eta

# def cal_plate_model(X_x, X_y, Y_xi, Y_eta):
#     # X_xy = np.array([np.ones_like(X_x), X_x, X_y, X_x ** 2, X_x * X_y, X_y ** 2, 
#     #              X_x ** 3, X_x ** 2 * X_y, X_x * X_y ** 2, X_y ** 3]).T
#     # X_xy = np.array([np.ones_like(X_x), X_x, X_y, X_x ** 2, X_x * X_y, X_y ** 2]).T
#     X_xy = np.array([np.ones_like(X_x), X_x, X_y, X_x ** 2, X_x * X_y, X_y ** 2]).T
    
#     A_CD1 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_xi

#     A_CD2 = np.linalg.inv(X_xy.T @ X_xy) @ X_xy.T @ Y_eta

#     A_CD = np.array([A_CD1, A_CD2])

#     return A_CD

# def use_plate_model(X_x, X_y, A_CD):
#     # X_xy = np.array([np.ones_like(X_x), X_x, X_y, X_x ** 2, X_x * X_y, X_y ** 2, 
#     #              X_x ** 3, X_x ** 2 * X_y, X_x * X_y ** 2, X_y ** 3]).T
#     X_xy = np.array([np.ones_like(X_x), X_x, X_y, X_x ** 2, X_x * X_y, X_y ** 2]).T
#     xi_eta = A_CD @ X_xy.T * (np.pi / 180)

#     return xi_eta

def write_ds9_region(filename, data, str_x, str_y):

    with open(filename, "w") as f:
        f.write(
            'global color=red dashlist=8 3 width=1 font="helvetica 10 normal roman" '
            "select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1"
            + "\n"
        )
        f.write("physical" + "\n")
        for i in range(len(data)):
            f.write(
                "circle("
                + str("%12.6f" % (data[str_x][i]))
                + ",  "
                + str("%12.6f" % (9232 - data[str_y][i]))
                + ","
                + str(15)
                + ")"
                + "\n"
            )

def match_box_id(points_x, points_y, bins_x, bins_y):
    # bins_x_id and bins_y_id
    bins_x_id = np.digitize(points_x, bins_x) - 1
    bins_y_id = np.digitize(points_y, bins_y) - 1

    return bins_x_id, bins_y_id


def cal_distort_model(dis_res_xy_list, bins_x, bins_y, bins_num, distort_sum_bins, distort_sum_values_x, distort_sum_values_y):

    for points_inf in dis_res_xy_list:
        points_x = points_inf[0, :]
        points_y = points_inf[1, :]
        distort_value_x = points_inf[2, :]
        distort_value_y = points_inf[3, :]

        bins_x_id, bins_y_id = match_box_id(points_x, points_y, bins_x, bins_y)

        distort_bins, _, _ = np.histogram2d(bins_x_id, bins_y_id, bins=(range(bins_num + 1), range(bins_num + 1)))
        distort_values_x, _, _ = np.histogram2d(bins_x_id, bins_y_id, bins=(range(bins_num + 1), range(bins_num + 1)),
                                                weights=distort_value_x)
        distort_values_y, _, _ = np.histogram2d(bins_x_id, bins_y_id, bins=(range(bins_num + 1), range(bins_num + 1)),
                                                weights=distort_value_y)

        distort_sum_bins += distort_bins
        distort_sum_values_x += distort_values_x
        distort_sum_values_y += distort_values_y

    return distort_sum_bins, distort_sum_values_x, distort_sum_values_y

def sigma_filter(data, data_rel, sigma_scale):

    mean_data = np.mean(data)
    std_data = np.std(data)
    # 小于μ-3σ或大于μ+3σ的数据均为异常值
    filter = (mean_data - sigma_scale * std_data < data) & (mean_data + sigma_scale * std_data > data)

    data_filter = data[filter]
    data_rel_filter = data_rel[filter]

    return data_filter, data_rel_filter

def sigma_filter_2(data1, data2, data_rel, sigma_scale):

    mean_data1 = np.mean(data1)
    std_data1 = np.std(data1)

    mean_data2 = np.mean(data2)
    std_data2 = np.std(data2)
    # 小于μ-3σ或大于μ+3σ的数据均为异常值
    filter1 = (data1 > mean_data1 - sigma_scale * std_data1) & (data1 < mean_data1 + sigma_scale * std_data1)
    filter2 = (data2 > mean_data2 - sigma_scale * std_data2) & (data1 < mean_data2 + sigma_scale * std_data2)

    filter = filter1 & filter2

    data1_filter = data1[filter]
    data2_filter = data2[filter]
    data_rel_filter = data_rel[filter]

    return data1_filter, data2_filter, data_rel_filter, filter

# %% [markdown]
# ### 文件路径

# %%
CONFIG_PATH = "/home/fangwf/software/miniconda3/envs/csst_mci/lib/python3.11/site-packages/csst_mci_astrometry/data_validate/"

band = "C1"
obs_index = "07"
unkonw_index = "01"

obs_info = {"01": "20240119020742_20240119021242", "02" :"20240119021141_20240119021641", "03": "20240119021742_20240119022242", "04": "20240119022342_20240119022842", "05": "20240119022941_20240119023441"}

img_path: str = f'/home/fangwf/MCI_SimData/240119/L1/ins/CSST_MCI_{band}_STAR_{obs_info[unkonw_index]}_202000000{unkonw_index}_{obs_index}_L1_V01_img.fits'
flg_path: str = f'/home/fangwf/MCI_SimData/240119/L1/ins/CSST_MCI_{band}_STAR_{obs_info[unkonw_index]}_202000000{unkonw_index}_{obs_index}_L1_V01_flg.fits'
wht_path: str = f'/home/fangwf/MCI_SimData/240119/L1/ins/CSST_MCI_{band}_STAR_{obs_info[unkonw_index]}_202000000{unkonw_index}_{obs_index}_L1_V01_wht.fits'

sext_config_path: str = CONFIG_PATH + "default.sex"
sext_para_path: str = CONFIG_PATH + "default.param"
sext_filter_path: str = CONFIG_PATH + "default.conv"
sext_out_path: str = os.path.basename(img_path).replace(".fits", ".acat")

# %%
hdu_img = fits.open(img_path)
hdu_img_header = hdu_img[1].header
pointing_ra, pointing_dec = hdu_img_header["CRVAL1"], hdu_img_header["CRVAL2"]
CD1_1, CD1_2, CD2_1, CD2_2 = hdu_img_header["CD1_1"], hdu_img_header["CD1_2"], hdu_img_header["CD2_1"], hdu_img_header["CD2_2"]
x_ref, y_ref = hdu_img_header["CRPIX1"], hdu_img_header["CRPIX2"]

# %%
print(f"reference point pixel, {x_ref}, {y_ref}")
print(f"reference point celestical, {pointing_ra}, {pointing_dec}")
# Out:
# reference point pixel, 4607.5, 4615.5
# reference point celestical, 265.1745710308334, -54.09801556935517

# %% [markdown]
# ### source-extractor结果筛选

# %%
fp_img = img_path
fp_flg = flg_path
fp_wht = wht_path
fp_config_sext = sext_config_path
fp_out_sext = sext_out_path
fp_para_sext = sext_para_path
fp_filter_sext = sext_filter_path

work_sext(fp_img,fp_config_sext,fp_out_sext, fp_flg, fp_wht, fp_para_sext,fp_filter_sext)
hdu_list =  fits.open(fp_out_sext)
hdu_list.info()
sext_out = Table(hdu_list[2].data)
# Out:
# >
# ----- SExtractor 2.25.0 started on 2024-03-07 at 21:41:07 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing catalog
# > Looking for CSST_MCI_C1_STAR_20240119020742_20240119021242_20200000001_07_L1_V01_img.fits
# ----- Measuring from: CSST_MCI_C1_STAR_20240119020742_20240119021242_20200000001_07_L1_V01_img.fits [1/1]
#       "Unnamed" / EXT. HEADER / 9216x9232 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   16
# > Setting up background map at line:   32
# > Setting up background map at line:   48
# > Setting up background map at line:   64
# > Setting up background map at line:   80
# > Setting up background map at line:   96
# > Setting up background map at line:  112
# > Setting up background map at line:  128
# > Setting up background map at line:  144
# > Setting up background map at line:  160
# > Setting up background map at line:  176
# > Setting up background map at line:  192
# > Setting up background map at line:  208
# > Setting up background map at line:  224
# > Setting up background map at line:  240
# > Setting up background map at line:  256
# > Setting up background map at line:  272
# > Setting up background map at line:  288
# > Setting up background map at line:  304
# > Setting up background map at line:  320
# > Setting up background map at line:  336
# > Setting up background map at line:  352
# > Setting up background map at line:  368
# > Setting up background map at line:  384
# > Setting up background map at line:  400
# > Setting up background map at line:  416
# > Setting up background map at line:  432
# > Setting up background map at line:  448
# > Setting up background map at line:  464
# > Setting up background map at line:  480
# > Setting up background map at line:  496
# > Setting up background map at line:  512
# > Setting up background map at line:  528
# > Setting up background map at line:  544
# > Setting up background map at line:  560
# > Setting up background map at line:  576
# > Setting up background map at line:  592
# > Setting up background map at line:  608
# > Setting up background map at line:  624
# > Setting up background map at line:  640
# > Setting up background map at line:  656
# > Setting up background map at line:  672
# > Setting up background map at line:  688
# > Setting up background map at line:  704
# > Setting up background map at line:  720
# > Setting up background map at line:  736
# > Setting up background map at line:  752
# > Setting up background map at line:  768
# > Setting up background map at line:  784
# > Setting up background map at line:  800
# > Setting up background map at line:  816
# > Setting up background map at line:  832
# > Setting up background map at line:  848
# > Setting up background map at line:  864
# > Setting up background map at line:  880
# > Setting up background map at line:  896
# > Setting up background map at line:  912
# > Setting up background map at line:  928
# > Setting up background map at line:  944
# > Setting up background map at line:  960
# > Setting up background map at line:  976
# > Setting up background map at line:  992
# > Setting up background map at line: 1008
# > Setting up background map at line: 1024
# > Setting up background map at line: 1040
# > Setting up background map at line: 1056
# > Setting up background map at line: 1072
# > Setting up background map at line: 1088
# > Setting up background map at line: 1104
# > Setting up background map at line: 1120
# > Setting up background map at line: 1136
# > Setting up background map at line: 1152
# > Setting up background map at line: 1168
# > Setting up background map at line: 1184
# > Setting up background map at line: 1200
# > Setting up background map at line: 1216
# > Setting up background map at line: 1232
# > Setting up background map at line: 1248
# > Setting up background map at line: 1264
# > Setting up background map at line: 1280
# > Setting up background map at line: 1296
# > Setting up background map at line: 1312
# > Setting up background map at line: 1328
# > Setting up background map at line: 1344
# > Setting up background map at line: 1360
# > Setting up background map at line: 1376
# > Setting up background map at line: 1392
# > Setting up background map at line: 1408
# > Setting up background map at line: 1424
# > Setting up background map at line: 1440
# > Setting up background map at line: 1456
# > Setting up background map at line: 1472
# > Setting up background map at line: 1488
# > Setting up background map at line: 1504
# > Setting up background map at line: 1520
# > Setting up background map at line: 1536
# > Setting up background map at line: 1552
# > Setting up background map at line: 1568
# > Setting up background map at line: 1584
# > Setting up background map at line: 1600
# > Setting up background map at line: 1616
# > Setting up background map at line: 1632
# > Setting up background map at line: 1648
# > Setting up background map at line: 1664
# > Setting up background map at line: 1680
# > Setting up background map at line: 1696
# > Setting up background map at line: 1712
# > Setting up background map at line: 1728
# > Setting up background map at line: 1744
# > Setting up background map at line: 1760
# > Setting up background map at line: 1776
# > Setting up background map at line: 1792
# > Setting up background map at line: 1808
# > Setting up background map at line: 1824
# > Setting up background map at line: 1840
# > Setting up background map at line: 1856
# > Setting up background map at line: 1872
# > Setting up background map at line: 1888
# > Setting up background map at line: 1904
# > Setting up background map at line: 1920
# > Setting up background map at line: 1936
# > Setting up background map at line: 1952
# > Setting up background map at line: 1968
# > Setting up background map at line: 1984
# > Setting up background map at line: 2000
# > Setting up background map at line: 2016
# > Setting up background map at line: 2032
# > Setting up background map at line: 2048
# > Setting up background map at line: 2064
# > Setting up background map at line: 2080
# > Setting up background map at line: 2096
# > Setting up background map at line: 2112
# > Setting up background map at line: 2128
# > Setting up background map at line: 2144
# > Setting up background map at line: 2160
# > Setting up background map at line: 2176
# > Setting up background map at line: 2192
# > Setting up background map at line: 2208
# > Setting up background map at line: 2224
# > Setting up background map at line: 2240
# > Setting up background map at line: 2256
# > Setting up background map at line: 2272
# > Setting up background map at line: 2288
# > Setting up background map at line: 2304
# > Setting up background map at line: 2320
# > Setting up background map at line: 2336
# > Setting up background map at line: 2352
# > Setting up background map at line: 2368
# > Setting up background map at line: 2384
# > Setting up background map at line: 2400
# > Setting up background map at line: 2416
# > Setting up background map at line: 2432
# > Setting up background map at line: 2448
# > Setting up background map at line: 2464
# > Setting up background map at line: 2480
# > Setting up background map at line: 2496
# > Setting up background map at line: 2512
# > Setting up background map at line: 2528
# > Setting up background map at line: 2544
# > Setting up background map at line: 2560
# > Setting up background map at line: 2576
# > Setting up background map at line: 2592
# > Setting up background map at line: 2608
# > Setting up background map at line: 2624
# > Setting up background map at line: 2640
# > Setting up background map at line: 2656
# > Setting up background map at line: 2672
# > Setting up background map at line: 2688
# > Setting up background map at line: 2704
# > Setting up background map at line: 2720
# > Setting up background map at line: 2736
# > Setting up background map at line: 2752
# > Setting up background map at line: 2768
# > Setting up background map at line: 2784
# > Setting up background map at line: 2800
# > Setting up background map at line: 2816
# > Setting up background map at line: 2832
# > Setting up background map at line: 2848
# > Setting up background map at line: 2864
# > Setting up background map at line: 2880
# > Setting up background map at line: 2896
# > Setting up background map at line: 2912
# > Setting up background map at line: 2928
# > Setting up background map at line: 2944
# > Setting up background map at line: 2960
# > Setting up background map at line: 2976
# > Setting up background map at line: 2992
# > Setting up background map at line: 3008
# > Setting up background map at line: 3024
# > Setting up background map at line: 3040
# > Setting up background map at line: 3056
# > Setting up background map at line: 3072
# > Setting up background map at line: 3088
# > Setting up background map at line: 3104
# > Setting up background map at line: 3120
# > Setting up background map at line: 3136
# > Setting up background map at line: 3152
# > Setting up background map at line: 3168
# > Setting up background map at line: 3184
# > Setting up background map at line: 3200
# > Setting up background map at line: 3216
# > Setting up background map at line: 3232
# > Setting up background map at line: 3248
# > Setting up background map at line: 3264
# > Setting up background map at line: 3280
# > Setting up background map at line: 3296
# > Setting up background map at line: 3312
# > Setting up background map at line: 3328
# > Setting up background map at line: 3344
# > Setting up background map at line: 3360
# > Setting up background map at line: 3376
# > Setting up background map at line: 3392
# > Setting up background map at line: 3408
# > Setting up background map at line: 3424
# > Setting up background map at line: 3440
# > Setting up background map at line: 3456
# > Setting up background map at line: 3472
# > Setting up background map at line: 3488
# > Setting up background map at line: 3504
# > Setting up background map at line: 3520
# > Setting up background map at line: 3536
# > Setting up background map at line: 3552
# > Setting up background map at line: 3568
# > Setting up background map at line: 3584
# > Setting up background map at line: 3600
# > Setting up background map at line: 3616
# > Setting up background map at line: 3632
# > Setting up background map at line: 3648
# > Setting up background map at line: 3664
# > Setting up background map at line: 3680
# > Setting up background map at line: 3696
# > Setting up background map at line: 3712
# > Setting up background map at line: 3728
# > Setting up background map at line: 3744
# > Setting up background map at line: 3760
# > Setting up background map at line: 3776
# > Setting up background map at line: 3792
# > Setting up background map at line: 3808
# > Setting up background map at line: 3824
# > Setting up background map at line: 3840
# > Setting up background map at line: 3856
# > Setting up background map at line: 3872
# > Setting up background map at line: 3888
# > Setting up background map at line: 3904
# > Setting up background map at line: 3920
# > Setting up background map at line: 3936
# > Setting up background map at line: 3952
# > Setting up background map at line: 3968
# > Setting up background map at line: 3984
# > Setting up background map at line: 4000
# > Setting up background map at line: 4016
# > Setting up background map at line: 4032
# > Setting up background map at line: 4048
# > Setting up background map at line: 4064
# > Setting up background map at line: 4080
# > Setting up background map at line: 4096
# > Setting up background map at line: 4112
# > Setting up background map at line: 4128
# > Setting up background map at line: 4144
# > Setting up background map at line: 4160
# > Setting up background map at line: 4176
# > Setting up background map at line: 4192
# > Setting up background map at line: 4208
# > Setting up background map at line: 4224
# > Setting up background map at line: 4240
# > Setting up background map at line: 4256
# > Setting up background map at line: 4272
# > Setting up background map at line: 4288
# > Setting up background map at line: 4304
# > Setting up background map at line: 4320
# > Setting up background map at line: 4336
# > Setting up background map at line: 4352
# > Setting up background map at line: 4368
# > Setting up background map at line: 4384
# > Setting up background map at line: 4400
# > Setting up background map at line: 4416
# > Setting up background map at line: 4432
# > Setting up background map at line: 4448
# > Setting up background map at line: 4464
# > Setting up background map at line: 4480
# > Setting up background map at line: 4496
# > Setting up background map at line: 4512
# > Setting up background map at line: 4528
# > Setting up background map at line: 4544
# > Setting up background map at line: 4560
# > Setting up background map at line: 4576
# > Setting up background map at line: 4592
# > Setting up background map at line: 4608
# > Setting up background map at line: 4624
# > Setting up background map at line: 4640
# > Setting up background map at line: 4656
# > Setting up background map at line: 4672
# > Setting up background map at line: 4688
# > Setting up background map at line: 4704
# > Setting up background map at line: 4720
# > Setting up background map at line: 4736
# > Setting up background map at line: 4752
# > Setting up background map at line: 4768
# > Setting up background map at line: 4784
# > Setting up background map at line: 4800
# > Setting up background map at line: 4816
# > Setting up background map at line: 4832
# > Setting up background map at line: 4848
# > Setting up background map at line: 4864
# > Setting up background map at line: 4880
# > Setting up background map at line: 4896
# > Setting up background map at line: 4912
# > Setting up background map at line: 4928
# > Setting up background map at line: 4944
# > Setting up background map at line: 4960
# > Setting up background map at line: 4976
# > Setting up background map at line: 4992
# > Setting up background map at line: 5008
# > Setting up background map at line: 5024
# > Setting up background map at line: 5040
# > Setting up background map at line: 5056
# > Setting up background map at line: 5072
# > Setting up background map at line: 5088
# > Setting up background map at line: 5104
# > Setting up background map at line: 5120
# > Setting up background map at line: 5136
# > Setting up background map at line: 5152
# > Setting up background map at line: 5168
# > Setting up background map at line: 5184
# > Setting up background map at line: 5200
# > Setting up background map at line: 5216
# > Setting up background map at line: 5232
# > Setting up background map at line: 5248
# > Setting up background map at line: 5264
# > Setting up background map at line: 5280
# > Setting up background map at line: 5296
# > Setting up background map at line: 5312
# > Setting up background map at line: 5328
# > Setting up background map at line: 5344
# > Setting up background map at line: 5360
# > Setting up background map at line: 5376
# > Setting up background map at line: 5392
# > Setting up background map at line: 5408
# > Setting up background map at line: 5424
# > Setting up background map at line: 5440
# > Setting up background map at line: 5456
# > Setting up background map at line: 5472
# > Setting up background map at line: 5488
# > Setting up background map at line: 5504
# > Setting up background map at line: 5520
# > Setting up background map at line: 5536
# > Setting up background map at line: 5552
# > Setting up background map at line: 5568
# > Setting up background map at line: 5584
# > Setting up background map at line: 5600
# > Setting up background map at line: 5616
# > Setting up background map at line: 5632
# > Setting up background map at line: 5648
# > Setting up background map at line: 5664
# > Setting up background map at line: 5680
# > Setting up background map at line: 5696
# > Setting up background map at line: 5712
# > Setting up background map at line: 5728
# > Setting up background map at line: 5744
# > Setting up background map at line: 5760
# > Setting up background map at line: 5776
# > Setting up background map at line: 5792
# > Setting up background map at line: 5808
# > Setting up background map at line: 5824
# > Setting up background map at line: 5840
# > Setting up background map at line: 5856
# > Setting up background map at line: 5872
# > Setting up background map at line: 5888
# > Setting up background map at line: 5904
# > Setting up background map at line: 5920
# > Setting up background map at line: 5936
# > Setting up background map at line: 5952
# > Setting up background map at line: 5968
# > Setting up background map at line: 5984
# > Setting up background map at line: 6000
# > Setting up background map at line: 6016
# > Setting up background map at line: 6032
# > Setting up background map at line: 6048
# > Setting up background map at line: 6064
# > Setting up background map at line: 6080
# > Setting up background map at line: 6096
# > Setting up background map at line: 6112
# > Setting up background map at line: 6128
# > Setting up background map at line: 6144
# > Setting up background map at line: 6160
# > Setting up background map at line: 6176
# > Setting up background map at line: 6192
# > Setting up background map at line: 6208
# > Setting up background map at line: 6224
# > Setting up background map at line: 6240
# > Setting up background map at line: 6256
# > Setting up background map at line: 6272
# > Setting up background map at line: 6288
# > Setting up background map at line: 6304
# > Setting up background map at line: 6320
# > Setting up background map at line: 6336
# > Setting up background map at line: 6352
# > Setting up background map at line: 6368
# > Setting up background map at line: 6384
# > Setting up background map at line: 6400
# > Setting up background map at line: 6416
# > Setting up background map at line: 6432
# > Setting up background map at line: 6448
# > Setting up background map at line: 6464
# > Setting up background map at line: 6480
# > Setting up background map at line: 6496
# > Setting up background map at line: 6512
# > Setting up background map at line: 6528
# > Setting up background map at line: 6544
# > Setting up background map at line: 6560
# > Setting up background map at line: 6576
# > Setting up background map at line: 6592
# > Setting up background map at line: 6608
# > Setting up background map at line: 6624
# > Setting up background map at line: 6640
# > Setting up background map at line: 6656
# > Setting up background map at line: 6672
# > Setting up background map at line: 6688
# > Setting up background map at line: 6704
# > Setting up background map at line: 6720
# > Setting up background map at line: 6736
# > Setting up background map at line: 6752
# > Setting up background map at line: 6768
# > Setting up background map at line: 6784
# > Setting up background map at line: 6800
# > Setting up background map at line: 6816
# > Setting up background map at line: 6832
# > Setting up background map at line: 6848
# > Setting up background map at line: 6864
# > Setting up background map at line: 6880
# > Setting up background map at line: 6896
# > Setting up background map at line: 6912
# > Setting up background map at line: 6928
# > Setting up background map at line: 6944
# > Setting up background map at line: 6960
# > Setting up background map at line: 6976
# > Setting up background map at line: 6992
# > Setting up background map at line: 7008
# > Setting up background map at line: 7024
# > Setting up background map at line: 7040
# > Setting up background map at line: 7056
# > Setting up background map at line: 7072
# > Setting up background map at line: 7088
# > Setting up background map at line: 7104
# > Setting up background map at line: 7120
# > Setting up background map at line: 7136
# > Setting up background map at line: 7152
# > Setting up background map at line: 7168
# > Setting up background map at line: 7184
# > Setting up background map at line: 7200
# > Setting up background map at line: 7216
# > Setting up background map at line: 7232
# > Setting up background map at line: 7248
# > Setting up background map at line: 7264
# > Setting up background map at line: 7280
# > Setting up background map at line: 7296
# > Setting up background map at line: 7312
# > Setting up background map at line: 7328
# > Setting up background map at line: 7344
# > Setting up background map at line: 7360
# > Setting up background map at line: 7376
# > Setting up background map at line: 7392
# > Setting up background map at line: 7408
# > Setting up background map at line: 7424
# > Setting up background map at line: 7440
# > Setting up background map at line: 7456
# > Setting up background map at line: 7472
# > Setting up background map at line: 7488
# > Setting up background map at line: 7504
# > Setting up background map at line: 7520
# > Setting up background map at line: 7536
# > Setting up background map at line: 7552
# > Setting up background map at line: 7568
# > Setting up background map at line: 7584
# > Setting up background map at line: 7600
# > Setting up background map at line: 7616
# > Setting up background map at line: 7632
# > Setting up background map at line: 7648
# > Setting up background map at line: 7664
# > Setting up background map at line: 7680
# > Setting up background map at line: 7696
# > Setting up background map at line: 7712
# > Setting up background map at line: 7728
# > Setting up background map at line: 7744
# > Setting up background map at line: 7760
# > Setting up background map at line: 7776
# > Setting up background map at line: 7792
# > Setting up background map at line: 7808
# > Setting up background map at line: 7824
# > Setting up background map at line: 7840
# > Setting up background map at line: 7856
# > Setting up background map at line: 7872
# > Setting up background map at line: 7888
# > Setting up background map at line: 7904
# > Setting up background map at line: 7920
# > Setting up background map at line: 7936
# > Setting up background map at line: 7952
# > Setting up background map at line: 7968
# > Setting up background map at line: 7984
# > Setting up background map at line: 8000
# > Setting up background map at line: 8016
# > Setting up background map at line: 8032
# > Setting up background map at line: 8048
# > Setting up background map at line: 8064
# > Setting up background map at line: 8080
# > Setting up background map at line: 8096
# > Setting up background map at line: 8112
# > Setting up background map at line: 8128
# > Setting up background map at line: 8144
# > Setting up background map at line: 8160
# > Setting up background map at line: 8176
# > Setting up background map at line: 8192
# > Setting up background map at line: 8208
# > Setting up background map at line: 8224
# > Setting up background map at line: 8240
# > Setting up background map at line: 8256
# > Setting up background map at line: 8272
# > Setting up background map at line: 8288
# > Setting up background map at line: 8304
# > Setting up background map at line: 8320
# > Setting up background map at line: 8336
# > Setting up background map at line: 8352
# > Setting up background map at line: 8368
# > Setting up background map at line: 8384
# > Setting up background map at line: 8400
# > Setting up background map at line: 8416
# > Setting up background map at line: 8432
# > Setting up background map at line: 8448
# > Setting up background map at line: 8464
# > Setting up background map at line: 8480
# > Setting up background map at line: 8496
# > Setting up background map at line: 8512
# > Setting up background map at line: 8528
# > Setting up background map at line: 8544
# > Setting up background map at line: 8560
# > Setting up background map at line: 8576
# > Setting up background map at line: 8592
# > Setting up background map at line: 8608
# > Setting up background map at line: 8624
# > Setting up background map at line: 8640
# > Setting up background map at line: 8656
# > Setting up background map at line: 8672
# > Setting up background map at line: 8688
# > Setting up background map at line: 8704
# > Setting up background map at line: 8720
# > Setting up background map at line: 8736
# > Setting up background map at line: 8752
# > Setting up background map at line: 8768
# > Setting up background map at line: 8784
# > Setting up background map at line: 8800
# > Setting up background map at line: 8816
# > Setting up background map at line: 8832
# > Setting up background map at line: 8848
# > Setting up background map at line: 8864
# > Setting up background map at line: 8880
# > Setting up background map at line: 8896
# > Setting up background map at line: 8912
# > Setting up background map at line: 8928
# > Setting up background map at line: 8944
# > Setting up background map at line: 8960
# > Setting up background map at line: 8976
# > Setting up background map at line: 8992
# > Setting up background map at line: 9008
# > Setting up background map at line: 9024
# > Setting up background map at line: 9040
# > Setting up background map at line: 9056
# > Setting up background map at line: 9072
# > Setting up background map at line: 9088
# > Setting up background map at line: 9104
# > Setting up background map at line: 9120
# > Setting up background map at line: 9136
# > Setting up background map at line: 9152
# > Setting up background map at line: 9168
# > Setting up background map at line: 9184
# > Setting up background map at line: 9200
# > Setting up background map at line: 9216
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0.0155617  RMS: 0.0173167  / Threshold: 0.05195
# > Scanning image
# > Line:   25  Objects:       14 detected /        0 sextracted
# > Line:   50  Objects:       36 detected /        0 sextracted
# > Line:   75  Objects:       57 detected /        0 sextracted
# > Line:  100  Objects:       71 detected /        0 sextracted
# > Line:  125  Objects:       89 detected /        0 sextracted
# > Line:  150  Objects:      105 detected /        0 sextracted
# > Line:  175  Objects:      128 detected /        0 sextracted
# > Line:  200  Objects:      144 detected /        0 sextracted
# > Line:  225  Objects:      161 detected /        0 sextracted
# > Line:  250  Objects:      184 detected /        0 sextracted
# > Line:  275  Objects:      209 detected /        0 sextracted
# > Line:  300  Objects:      233 detected /        0 sextracted
# > Line:  325  Objects:      245 detected /        0 sextracted
# > Line:  350  Objects:      255 detected /        0 sextracted
# > Line:  375  Objects:      279 detected /        0 sextracted
# > Line:  400  Objects:      298 detected /        0 sextracted
# > Line:  425  Objects:      316 detected /        0 sextracted
# > Line:  450  Objects:      345 detected /        0 sextracted
# > Line:  475  Objects:      368 detected /        0 sextracted
# > Line:  500  Objects:      383 detected /        0 sextracted
# > Line:  525  Objects:      408 detected /        0 sextracted
# > Line:  550  Objects:      439 detected /        0 sextracted
# > Line:  575  Objects:      468 detected /        0 sextracted
# > Line:  600  Objects:      491 detected /        0 sextracted
# > Line:  625  Objects:      514 detected /        0 sextracted
# > Line:  650  Objects:      540 detected /        0 sextracted
# > Line:  675  Objects:      557 detected /        0 sextracted
# > Line:  700  Objects:      593 detected /        0 sextracted
# > Line:  725  Objects:      623 detected /        0 sextracted
# > Line:  750  Objects:      648 detected /        0 sextracted
# > Line:  775  Objects:      669 detected /        0 sextracted
# > Line:  800  Objects:      686 detected /        0 sextracted
# > Line:  825  Objects:      712 detected /        0 sextracted
# > Line:  850  Objects:      729 detected /        0 sextracted
# > Line:  875  Objects:      746 detected /        0 sextracted
# > Line:  900  Objects:      769 detected /        0 sextracted
# > Line:  925  Objects:      786 detected /        0 sextracted
# > Line:  950  Objects:      801 detected /        0 sextracted
# > Line:  975  Objects:      815 detected /        0 sextracted
# > Line: 1000  Objects:      836 detected /        0 sextracted
# > Line: 1022  Objects:      852 detected /        0 sextracted
# > Line: 1025  Objects:      853 detected /       20 sextracted
# > Line: 1050  Objects:      880 detected /       47 sextracted
# > Line: 1075  Objects:      905 detected /       68 sextracted
# > Line: 1100  Objects:      928 detected /       86 sextracted
# > Line: 1125  Objects:      948 detected /      101 sextracted
# > Line: 1150  Objects:      974 detected /      118 sextracted
# > Line: 1175  Objects:      989 detected /      137 sextracted
# > Line: 1200  Objects:     1003 detected /      156 sextracted
# > Line: 1225  Objects:     1022 detected /      174 sextracted
# > Line: 1250  Objects:     1038 detected /      199 sextracted
# > Line: 1275  Objects:     1062 detected /      226 sextracted
# > Line: 1300  Objects:     1079 detected /      245 sextracted
# > Line: 1325  Objects:     1103 detected /      257 sextracted
# > Line: 1350  Objects:     1126 detected /      271 sextracted
# > Line: 1375  Objects:     1146 detected /      289 sextracted
# > Line: 1400  Objects:     1174 detected /      311 sextracted
# > Line: 1425  Objects:     1194 detected /      334 sextracted
# > Line: 1450  Objects:     1220 detected /      355 sextracted
# > Line: 1475  Objects:     1257 detected /      382 sextracted
# > Line: 1500  Objects:     1288 detected /      399 sextracted
# > Line: 1504  Objects:     1292 detected /      400 sextracted
# > Line: 1525  Objects:     1308 detected /      417 sextracted
# > Line: 1550  Objects:     1330 detected /      452 sextracted
# > Line: 1575  Objects:     1346 detected /      487 sextracted
# > Line: 1600  Objects:     1361 detected /      512 sextracted
# > Line: 1625  Objects:     1380 detected /      535 sextracted
# > Line: 1650  Objects:     1398 detected /      559 sextracted
# > Line: 1675  Objects:     1423 detected /      581 sextracted
# > Line: 1700  Objects:     1445 detected /      609 sextracted
# > Line: 1725  Objects:     1467 detected /      638 sextracted
# > Line: 1750  Objects:     1490 detected /      660 sextracted
# > Line: 1775  Objects:     1513 detected /      690 sextracted
# > Line: 1800  Objects:     1533 detected /      708 sextracted
# > Line: 1825  Objects:     1560 detected /      726 sextracted
# > Line: 1850  Objects:     1586 detected /      748 sextracted
# > Line: 1875  Objects:     1608 detected /      772 sextracted
# > Line: 1900  Objects:     1623 detected /      791 sextracted
# > Line: 1924  Objects:     1647 detected /      800 sextracted
# > Line: 1925  Objects:     1647 detected /      802 sextracted
# > Line: 1950  Objects:     1669 detected /      816 sextracted
# > Line: 1975  Objects:     1699 detected /      832 sextracted
# > Line: 2000  Objects:     1716 detected /      856 sextracted
# > Line: 2025  Objects:     1745 detected /      876 sextracted
# > Line: 2050  Objects:     1767 detected /      902 sextracted
# > Line: 2075  Objects:     1794 detected /      922 sextracted
# > Line: 2100  Objects:     1822 detected /      948 sextracted
# > Line: 2125  Objects:     1847 detected /      965 sextracted
# > Line: 2150  Objects:     1875 detected /      992 sextracted
# > Line: 2175  Objects:     1894 detected /     1012 sextracted
# > Line: 2200  Objects:     1917 detected /     1027 sextracted
# > Line: 2225  Objects:     1941 detected /     1051 sextracted
# > Line: 2250  Objects:     1966 detected /     1065 sextracted
# > Line: 2275  Objects:     1984 detected /     1080 sextracted
# > Line: 2300  Objects:     2000 detected /     1102 sextracted
# > Line: 2325  Objects:     2018 detected /     1120 sextracted
# > Line: 2350  Objects:     2044 detected /     1142 sextracted
# > Line: 2375  Objects:     2068 detected /     1171 sextracted
# > Line: 2400  Objects:     2085 detected /     1190 sextracted
# > Line: 2412  Objects:     2100 detected /     1200 sextracted
# > Line: 2425  Objects:     2110 detected /     1213 sextracted
# > Line: 2450  Objects:     2124 detected /     1236 sextracted
# > Line: 2475  Objects:     2143 detected /     1271 sextracted
# > Line: 2500  Objects:     2167 detected /     1302 sextracted
# > Line: 2525  Objects:     2185 detected /     1324 sextracted
# > Line: 2550  Objects:     2197 detected /     1341 sextracted
# > Line: 2575  Objects:     2220 detected /     1357 sextracted
# > Line: 2600  Objects:     2247 detected /     1375 sextracted
# > Line: 2625  Objects:     2271 detected /     1398 sextracted
# > Line: 2650  Objects:     2293 detected /     1417 sextracted
# > Line: 2675  Objects:     2309 detected /     1440 sextracted
# > Line: 2700  Objects:     2333 detected /     1461 sextracted
# > Line: 2725  Objects:     2356 detected /     1482 sextracted
# > Line: 2750  Objects:     2370 detected /     1502 sextracted
# > Line: 2775  Objects:     2389 detected /     1529 sextracted
# > Line: 2800  Objects:     2414 detected /     1550 sextracted
# > Line: 2825  Objects:     2432 detected /     1573 sextracted
# > Line: 2850  Objects:     2453 detected /     1594 sextracted
# > Line: 2857  Objects:     2462 detected /     1600 sextracted
# > Line: 2875  Objects:     2476 detected /     1625 sextracted
# > Line: 2900  Objects:     2500 detected /     1645 sextracted
# > Line: 2925  Objects:     2513 detected /     1663 sextracted
# > Line: 2950  Objects:     2538 detected /     1678 sextracted
# > Line: 2975  Objects:     2563 detected /     1707 sextracted
# > Line: 3000  Objects:     2587 detected /     1733 sextracted
# > Line: 3025  Objects:     2607 detected /     1756 sextracted
# > Line: 3050  Objects:     2629 detected /     1781 sextracted
# > Line: 3075  Objects:     2645 detected /     1818 sextracted
# > Line: 3100  Objects:     2671 detected /     1842 sextracted
# > Line: 3125  Objects:     2701 detected /     1864 sextracted
# > Line: 3150  Objects:     2734 detected /     1884 sextracted
# > Line: 3175  Objects:     2764 detected /     1909 sextracted
# > Line: 3200  Objects:     2787 detected /     1932 sextracted
# > Line: 3225  Objects:     2809 detected /     1959 sextracted
# > Line: 3250  Objects:     2825 detected /     1978 sextracted
# > Line: 3275  Objects:     2843 detected /     1994 sextracted
# > Line: 3284  Objects:     2849 detected /     2000 sextracted
# > Line: 3300  Objects:     2859 detected /     2015 sextracted
# > Line: 3325  Objects:     2875 detected /     2039 sextracted
# > Line: 3350  Objects:     2889 detected /     2061 sextracted
# > Line: 3375  Objects:     2910 detected /     2085 sextracted
# > Line: 3400  Objects:     2940 detected /     2101 sextracted
# > Line: 3425  Objects:     2962 detected /     2125 sextracted
# > Line: 3450  Objects:     2978 detected /     2140 sextracted
# > Line: 3475  Objects:     3003 detected /     2161 sextracted
# > Line: 3500  Objects:     3027 detected /     2183 sextracted
# > Line: 3525  Objects:     3055 detected /     2202 sextracted
# > Line: 3550  Objects:     3083 detected /     2214 sextracted
# > Line: 3575  Objects:     3096 detected /     2238 sextracted
# > Line: 3600  Objects:     3116 detected /     2264 sextracted
# > Line: 3625  Objects:     3145 detected /     2280 sextracted
# > Line: 3650  Objects:     3167 detected /     2306 sextracted
# > Line: 3675  Objects:     3194 detected /     2330 sextracted
# > Line: 3700  Objects:     3212 detected /     2349 sextracted
# > Line: 3725  Objects:     3233 detected /     2370 sextracted
# > Line: 3750  Objects:     3257 detected /     2388 sextracted
# > Line: 3763  Objects:     3274 detected /     2400 sextracted
# > Line: 3775  Objects:     3295 detected /     2413 sextracted
# > Line: 3800  Objects:     3321 detected /     2433 sextracted
# > Line: 3825  Objects:     3343 detected /     2452 sextracted
# > Line: 3850  Objects:     3359 detected /     2471 sextracted
# > Line: 3875  Objects:     3388 detected /     2491 sextracted
# > Line: 3900  Objects:     3404 detected /     2512 sextracted
# > Line: 3925  Objects:     3420 detected /     2531 sextracted
# > Line: 3950  Objects:     3441 detected /     2558 sextracted
# > Line: 3975  Objects:     3459 detected /     2580 sextracted
# > Line: 4000  Objects:     3485 detected /     2605 sextracted
# > Line: 4025  Objects:     3507 detected /     2624 sextracted
# > Line: 4050  Objects:     3524 detected /     2643 sextracted
# > Line: 4075  Objects:     3548 detected /     2664 sextracted
# > Line: 4100  Objects:     3583 detected /     2690 sextracted
# > Line: 4125  Objects:     3591 detected /     2719 sextracted
# > Line: 4150  Objects:     3609 detected /     2745 sextracted
# > Line: 4175  Objects:     3636 detected /     2777 sextracted
# > Line: 4200  Objects:     3657 detected /     2798 sextracted
# > Line: 4203  Objects:     3661 detected /     2800 sextracted
# > Line: 4225  Objects:     3692 detected /     2822 sextracted
# > Line: 4250  Objects:     3715 detected /     2834 sextracted
# > Line: 4275  Objects:     3740 detected /     2850 sextracted
# > Line: 4300  Objects:     3770 detected /     2871 sextracted
# > Line: 4325  Objects:     3802 detected /     2887 sextracted
# > Line: 4350  Objects:     3821 detected /     2902 sextracted
# > Line: 4375  Objects:     3852 detected /     2928 sextracted
# > Line: 4400  Objects:     3874 detected /     2950 sextracted
# > Line: 4425  Objects:     3897 detected /     2977 sextracted
# > Line: 4450  Objects:     3918 detected /     2991 sextracted
# > Line: 4475  Objects:     3946 detected /     3013 sextracted
# > Line: 4500  Objects:     3960 detected /     3036 sextracted
# > Line: 4525  Objects:     3976 detected /     3063 sextracted
# > Line: 4550  Objects:     3998 detected /     3093 sextracted
# > Line: 4575  Objects:     4021 detected /     3106 sextracted
# > Line: 4600  Objects:     4047 detected /     3125 sextracted
# > Line: 4625  Objects:     4063 detected /     3161 sextracted
# > Line: 4650  Objects:     4086 detected /     3189 sextracted
# > Line: 4663  Objects:     4099 detected /     3200 sextracted
# > Line: 4675  Objects:     4107 detected /     3209 sextracted
# > Line: 4700  Objects:     4132 detected /     3223 sextracted
# > Line: 4725  Objects:     4153 detected /     3249 sextracted
# > Line: 4750  Objects:     4165 detected /     3277 sextracted
# > Line: 4775  Objects:     4181 detected /     3312 sextracted
# > Line: 4800  Objects:     4206 detected /     3337 sextracted
# > Line: 4825  Objects:     4223 detected /     3354 sextracted
# > Line: 4850  Objects:     4250 detected /     3375 sextracted
# > Line: 4875  Objects:     4270 detected /     3400 sextracted
# > Line: 4900  Objects:     4283 detected /     3415 sextracted
# > Line: 4925  Objects:     4309 detected /     3433 sextracted
# > Line: 4950  Objects:     4324 detected /     3449 sextracted
# > Line: 4975  Objects:     4351 detected /     3468 sextracted
# > Line: 5000  Objects:     4372 detected /     3491 sextracted
# > Line: 5025  Objects:     4396 detected /     3520 sextracted
# > Line: 5050  Objects:     4418 detected /     3542 sextracted
# > Line: 5075  Objects:     4443 detected /     3568 sextracted
# > Line: 5100  Objects:     4474 detected /     3591 sextracted
# > Line: 5106  Objects:     4479 detected /     3600 sextracted
# > Line: 5125  Objects:     4496 detected /     3614 sextracted
# > Line: 5150  Objects:     4513 detected /     3635 sextracted
# > Line: 5175  Objects:     4533 detected /     3655 sextracted
# > Line: 5200  Objects:     4556 detected /     3679 sextracted
# > Line: 5225  Objects:     4584 detected /     3707 sextracted
# > Line: 5250  Objects:     4600 detected /     3736 sextracted
# > Line: 5275  Objects:     4622 detected /     3754 sextracted
# > Line: 5300  Objects:     4642 detected /     3785 sextracted
# > Line: 5325  Objects:     4667 detected /     3814 sextracted
# > Line: 5350  Objects:     4691 detected /     3836 sextracted
# > Line: 5375  Objects:     4714 detected /     3864 sextracted
# > Line: 5400  Objects:     4740 detected /     3888 sextracted
# > Line: 5425  Objects:     4770 detected /     3907 sextracted
# > Line: 5450  Objects:     4800 detected /     3931 sextracted
# > Line: 5475  Objects:     4821 detected /     3952 sextracted
# > Line: 5500  Objects:     4855 detected /     3970 sextracted
# > Line: 5525  Objects:     4877 detected /     3988 sextracted
# > Line: 5542  Objects:     4892 detected /     4000 sextracted
# > Line: 5550  Objects:     4895 detected /     4008 sextracted
# > Line: 5575  Objects:     4922 detected /     4035 sextracted
# > Line: 5600  Objects:     4949 detected /     4056 sextracted
# > Line: 5625  Objects:     4973 detected /     4074 sextracted
# > Line: 5650  Objects:     5000 detected /     4097 sextracted
# > Line: 5675  Objects:     5022 detected /     4125 sextracted
# > Line: 5700  Objects:     5047 detected /     4148 sextracted
# > Line: 5725  Objects:     5079 detected /     4169 sextracted
# > Line: 5750  Objects:     5106 detected /     4178 sextracted
# > Line: 5775  Objects:     5134 detected /     4195 sextracted
# > Line: 5800  Objects:     5154 detected /     4218 sextracted
# > Line: 5825  Objects:     5189 detected /     4243 sextracted
# > Line: 5850  Objects:     5212 detected /     4272 sextracted
# > Line: 5875  Objects:     5221 detected /     4289 sextracted
# > Line: 5900  Objects:     5245 detected /     4302 sextracted
# > Line: 5925  Objects:     5266 detected /     4322 sextracted
# > Line: 5950  Objects:     5287 detected /     4344 sextracted
# > Line: 5975  Objects:     5311 detected /     4369 sextracted
# > Line: 6000  Objects:     5335 detected /     4390 sextracted
# > Line: 6014  Objects:     5339 detected /     4400 sextracted
# > Line: 6025  Objects:     5347 detected /     4415 sextracted
# > Line: 6050  Objects:     5369 detected /     4437 sextracted
# > Line: 6075  Objects:     5393 detected /     4463 sextracted
# > Line: 6100  Objects:     5418 detected /     4492 sextracted
# > Line: 6125  Objects:     5443 detected /     4513 sextracted
# > Line: 6150  Objects:     5462 detected /     4534 sextracted
# > Line: 6175  Objects:     5479 detected /     4548 sextracted
# > Line: 6200  Objects:     5505 detected /     4572 sextracted
# > Line: 6225  Objects:     5529 detected /     4596 sextracted
# > Line: 6250  Objects:     5550 detected /     4617 sextracted
# > Line: 6275  Objects:     5571 detected /     4636 sextracted
# > Line: 6300  Objects:     5586 detected /     4656 sextracted
# > Line: 6325  Objects:     5609 detected /     4675 sextracted
# > Line: 6350  Objects:     5624 detected /     4706 sextracted
# > Line: 6375  Objects:     5650 detected /     4731 sextracted
# > Line: 6400  Objects:     5662 detected /     4758 sextracted
# > Line: 6425  Objects:     5681 detected /     4784 sextracted
# > Line: 6434  Objects:     5683 detected /     4800 sextracted
# > Line: 6450  Objects:     5701 detected /     4817 sextracted
# > Line: 6475  Objects:     5728 detected /     4843 sextracted
# > Line: 6500  Objects:     5743 detected /     4868 sextracted
# > Line: 6525  Objects:     5761 detected /     4895 sextracted
# > Line: 6550  Objects:     5789 detected /     4914 sextracted
# > Line: 6575  Objects:     5803 detected /     4936 sextracted
# > Line: 6600  Objects:     5816 detected /     4966 sextracted
# > Line: 6625  Objects:     5833 detected /     4989 sextracted
# > Line: 6650  Objects:     5853 detected /     5010 sextracted
# > Line: 6675  Objects:     5878 detected /     5039 sextracted
# > Line: 6700  Objects:     5901 detected /     5065 sextracted
# > Line: 6725  Objects:     5925 detected /     5096 sextracted
# > Line: 6750  Objects:     5946 detected /     5118 sextracted
# > Line: 6775  Objects:     5965 detected /     5143 sextracted
# > Line: 6800  Objects:     5982 detected /     5165 sextracted
# > Line: 6825  Objects:     6004 detected /     5200 sextracted
# > Line: 6826  Objects:     6005 detected /     5200 sextracted
# > Line: 6850  Objects:     6023 detected /     5218 sextracted
# > Line: 6875  Objects:     6047 detected /     5235 sextracted
# > Line: 6900  Objects:     6065 detected /     5257 sextracted
# > Line: 6925  Objects:     6078 detected /     5280 sextracted
# > Line: 6950  Objects:     6103 detected /     5300 sextracted
# > Line: 6975  Objects:     6117 detected /     5326 sextracted
# > Line: 7000  Objects:     6133 detected /     5345 sextracted
# > Line: 7025  Objects:     6165 detected /     5362 sextracted
# > Line: 7050  Objects:     6195 detected /     5384 sextracted
# > Line: 7075  Objects:     6228 detected /     5400 sextracted
# > Line: 7100  Objects:     6271 detected /     5431 sextracted
# > Line: 7125  Objects:     6302 detected /     5450 sextracted
# > Line: 7150  Objects:     6323 detected /     5474 sextracted
# > Line: 7175  Objects:     6354 detected /     5496 sextracted
# > Line: 7200  Objects:     6375 detected /     5521 sextracted
# > Line: 7225  Objects:     6398 detected /     5541 sextracted
# > Line: 7250  Objects:     6412 detected /     5565 sextracted
# > Line: 7275  Objects:     6436 detected /     5583 sextracted
# > Line: 7300  Objects:     6453 detected /     5597 sextracted
# > Line: 7304  Objects:     6455 detected /     5600 sextracted
# > Line: 7325  Objects:     6476 detected /     5618 sextracted
# > Line: 7350  Objects:     6494 detected /     5634 sextracted
# > Line: 7375  Objects:     6517 detected /     5659 sextracted
# > Line: 7400  Objects:     6528 detected /     5676 sextracted
# > Line: 7425  Objects:     6551 detected /     5696 sextracted
# > Line: 7450  Objects:     6575 detected /     5716 sextracted
# > Line: 7475  Objects:     6597 detected /     5740 sextracted
# > Line: 7500  Objects:     6616 detected /     5755 sextracted
# > Line: 7525  Objects:     6632 detected /     5781 sextracted
# > Line: 7550  Objects:     6659 detected /     5801 sextracted
# > Line: 7575  Objects:     6680 detected /     5817 sextracted
# > Line: 7600  Objects:     6705 detected /     5834 sextracted
# > Line: 7625  Objects:     6737 detected /     5852 sextracted
# > Line: 7650  Objects:     6755 detected /     5875 sextracted
# > Line: 7675  Objects:     6789 detected /     5900 sextracted
# > Line: 7700  Objects:     6817 detected /     5924 sextracted
# > Line: 7725  Objects:     6845 detected /     5943 sextracted
# > Line: 7750  Objects:     6886 detected /     5963 sextracted
# > Line: 7775  Objects:     6913 detected /     5981 sextracted
# > Line: 7800  Objects:     6948 detected /     5998 sextracted
# > Line: 7807  Objects:     6955 detected /     6000 sextracted
# > Line: 7825  Objects:     6970 detected /     6022 sextracted
# > Line: 7850  Objects:     6997 detected /     6039 sextracted
# > Line: 7875  Objects:     7010 detected /     6063 sextracted
# > Line: 7900  Objects:     7028 detected /     6083 sextracted
# > Line: 7925  Objects:     7038 detected /     6099 sextracted
# > Line: 7950  Objects:     7055 detected /     6121 sextracted
# > Line: 7975  Objects:     7081 detected /     6136 sextracted
# > Line: 8000  Objects:     7102 detected /     6152 sextracted
# > Line: 8025  Objects:     7123 detected /     6182 sextracted
# > Line: 8050  Objects:     7143 detected /     6207 sextracted
# > Line: 8075  Objects:     7170 detected /     6244 sextracted
# > Line: 8100  Objects:     7185 detected /     6287 sextracted
# > Line: 8125  Objects:     7208 detected /     6314 sextracted
# > Line: 8150  Objects:     7231 detected /     6340 sextracted
# > Line: 8175  Objects:     7254 detected /     6371 sextracted
# > Line: 8200  Objects:     7291 detected /     6387 sextracted
# > Line: 8217  Objects:     7309 detected /     6400 sextracted
# > Line: 8225  Objects:     7320 detected /     6406 sextracted
# > Line: 8250  Objects:     7349 detected /     6423 sextracted
# > Line: 8275  Objects:     7370 detected /     6450 sextracted
# > Line: 8300  Objects:     7395 detected /     6464 sextracted
# > Line: 8325  Objects:     7419 detected /     6489 sextracted
# > Line: 8350  Objects:     7441 detected /     6509 sextracted
# > Line: 8375  Objects:     7465 detected /     6533 sextracted
# > Line: 8400  Objects:     7489 detected /     6545 sextracted
# > Line: 8425  Objects:     7508 detected /     6565 sextracted
# > Line: 8450  Objects:     7537 detected /     6585 sextracted
# > Line: 8475  Objects:     7563 detected /     6607 sextracted
# > Line: 8500  Objects:     7587 detected /     6630 sextracted
# > Line: 8525  Objects:     7613 detected /     6649 sextracted
# > Line: 8550  Objects:     7640 detected /     6669 sextracted
# > Line: 8575  Objects:     7660 detected /     6693 sextracted
# > Line: 8600  Objects:     7676 detected /     6720 sextracted
# > Line: 8625  Objects:     7702 detected /     6749 sextracted
# > Line: 8650  Objects:     7724 detected /     6770 sextracted
# > Line: 8675  Objects:     7743 detected /     6800 sextracted
# > Line: 8675  Objects:     7743 detected /     6802 sextracted
# > Line: 8700  Objects:     7768 detected /     6833 sextracted
# > Line: 8725  Objects:     7791 detected /     6864 sextracted
# > Line: 8750  Objects:     7808 detected /     6898 sextracted
# > Line: 8775  Objects:     7822 detected /     6932 sextracted
# > Line: 8800  Objects:     7846 detected /     6959 sextracted
# > Line: 8825  Objects:     7872 detected /     6984 sextracted
# > Line: 8850  Objects:     7897 detected /     7003 sextracted
# > Line: 8875  Objects:     7927 detected /     7023 sextracted
# > Line: 8900  Objects:     7944 detected /     7039 sextracted
# > Line: 8925  Objects:     7968 detected /     7052 sextracted
# > Line: 8950  Objects:     7996 detected /     7076 sextracted
# > Line: 8975  Objects:     8011 detected /     7099 sextracted
# > Line: 9000  Objects:     8033 detected /     7119 sextracted
# > Line: 9025  Objects:     8055 detected /     7138 sextracted
# > Line: 9050  Objects:     8081 detected /     7161 sextracted
# > Line: 9075  Objects:     8096 detected /     7182 sextracted
# > Line: 9100  Objects:     8113 detected /     7200 sextracted
# > Line: 9103  Objects:     8115 detected /     7200 sextracted
# > Line: 9125  Objects:     8127 detected /     7220 sextracted
# > Line: 9150  Objects:     8144 detected /     7242 sextracted
# > Line: 9175  Objects:     8158 detected /     7265 sextracted
# > Line: 9200  Objects:     8171 detected /     7298 sextracted
# > Line: 9225  Objects:     8184 detected /     7334 sextracted
# > Line: 9232  Objects:     8188 detected /     7600 sextracted
# Filename: CSST_MCI_C1_STAR_20240119020742_20240119021242_20200000001_07_L1_V01_img.acat
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [13840A]
#   2  LDAC_OBJECTS    1 BinTableHDU     68   8188R x 15C   [1E, 1E, 1E, 1E, 1J, 1J, 1J, 1J, 1E, 1E, 1D, 1D, 1D, 1D, 1I]
# > Line: 9232  Objects:     8188 detected /     8000 sextracted
#       Objects: detected 8188     / sextracted 8188
#
# > Closing files
# >
# > All done (in 18.1 s: 508.7 lines/s , 451.1 detections/s)

# %%
log_path = "/home/fangwf/MCI_SimData/240119/L0/log_Data"
filename = "star_info_SN_1.fits"

hdu_info = fits.open(os.path.join(log_path, filename))
l0_info = Table(hdu_info[1].data)
filter_x = l0_info[f"posX_{band}"]
filter_y = 9232 - l0_info[f"posY_{band}"]
filter_mag = l0_info["st_magbp"]

# %%
sext_out["filter"] = 0
sext_out[f"mag_{band}"] = np.zeros_like(sext_out["filter"], dtype=float)

for l0_x, l0_y, l0_mag in zip(filter_x, filter_y, filter_mag):
    index = (sext_out["XWIN_IMAGE"] - l0_x) ** 2 + (sext_out["YWIN_IMAGE"] - l0_y) ** 2 < 4
    if np.sum(index) == 1:
        sext_out["filter"][index] = 1
        sext_out[f"mag_{band}"][index] = l0_mag

sext_out_filter = sext_out[sext_out["filter"] == 1]

# %%
sext_out_filter
# Out:
# <Table length=1408>
# FLUX_AUTO FLUXERR_AUTO  MAG_AUTO  MAGERR_AUTO ... FLAGS filter   mag_C1
#  float32    float32     float32     float32   ... int16 int64   float64
# --------- ------------ ---------- ----------- ... ----- ------ ---------
# 1197.3306     27.97605  -7.695535 0.025374772 ...     0      1 18.122917
#  661.4502    20.794205  -7.051243 0.034140904 ...     0      1 20.075052
#  293.4351     13.85108 -6.1687803  0.05126269 ...     0      1 19.990267
# 1318.5029    29.357792  -7.800203  0.02418088 ...     0      1 17.673443
# 161.81496    10.286734  -5.522547  0.06903807 ...     0      1 20.173918
#  5600.318    60.501976  -9.370532 0.011732396 ...     0      1 16.616312
# 424.91022    16.667065  -6.570743  0.04259825 ...     0      1 19.545483
# 234.05714    12.370934 -5.9233046 0.057399802 ...     0      1 21.244184
#  345.8392    15.036897 -6.3471856 0.047218677 ...     0      1 19.541704
# 2253.0457     38.37557  -8.381925  0.01849757 ...     0      1 17.498306
#       ...          ...        ...         ... ...   ...    ...       ...
# 582.00366    19.505505 -6.9123144  0.03639664 ...     0      1 18.851631
#  94.29874    7.8533335 -4.9362645  0.09044363 ...     0      1  20.93427
# 1155.0841    27.477997  -7.656534 0.025834573 ...     0      1  18.18727
# 1237.4951    28.441217 -7.7313585  0.02495942 ...     0      1 18.166435
#  88.19171     7.594658 -4.8635693 0.093521245 ...     0      1 21.038498
# 17577.836    107.18702 -10.612413 0.006622266 ...     0      1 15.439788
# 189.77637    11.139458 -5.6956053  0.06374583 ...     0      1 20.267138
# 187.54735    11.073873 -5.6827774 0.064123675 ...     0      1   20.4057
# 3336.5376    46.699627   -8.80824 0.015200127 ...     0      1  17.25712
# 2191.2935      37.8459  -8.351751 0.018756341 ...     0      1  17.42723

# %%
sext_out_filter[f"mag_{band}"][sext_out_filter["X_IMAGE"] == max(sext_out_filter["X_IMAGE"])]
# Out:
# <Column name='mag_C1' dtype='float64' length=1>
# 20.414103

# %% [markdown]
# ### 获取gaia星表

# %%
df = pd.read_csv(f"validate_test/result/CSST_MCI_{band}_STAR_{obs_info[unkonw_index]}_202000000{unkonw_index}_{obs_index}_L1_V01_img_out.txt", delimiter=" ")

refcat_ra_now = np.array(df["ra_J2025(deg)"])
refcat_dec_now = np.array(df["dec_J2025(deg)"])

refcat_ra_now_filter = refcat_ra_now[df["Gmag(mag)"] < np.percentile(df["Gmag(mag)"], 10)]
refcat_dec_now_filter = refcat_dec_now[df["Gmag(mag)"] < np.percentile(df["Gmag(mag)"], 10)]

# %%
ra_comb = np.array(list(itertools.combinations(refcat_ra_now_filter,3)))
dec_comb = np.array(list(itertools.combinations(refcat_dec_now_filter,3)))
refcat_lib = np.concatenate((ra_comb, dec_comb), axis=1)

for i, comb in enumerate(list(itertools.combinations([2, 1, 0], 2))):
    refcat_lib = np.column_stack((refcat_lib, pos_side(refcat_lib[:, comb[0]], refcat_lib[:, comb[0] + 3], refcat_lib[:, comb[1]], refcat_lib[:, comb[1] + 3])))

for i in range(len(refcat_lib)):
    temp_lib = refcat_lib[i, :]
    temp_lib_side = temp_lib[6:9]
    index_max = temp_lib_side == max(temp_lib_side)
    index_min = temp_lib_side == min(temp_lib_side)
    index_mid = ~(index_max | index_min)
    refcat_lib[i, :] = (temp_lib.reshape(3, 3) @ np.array([index_max, index_mid, index_min]).T).reshape(9)

refcat_lib = pd.DataFrame(refcat_lib, columns=['ra_1', 'ra_2', 'ra_3', 'dec_1', 'dec_2', 'dec_3', 'side_1', 'side_2', 'side_3'])

refcat_lib
# Out:
#               ra_1        ra_2        ra_3      dec_1      dec_2      dec_3  \
# 0       265.229547  265.219353  265.086876 -54.048800 -54.094112 -54.054815
# 1       265.219353  265.229547  265.103242 -54.094112 -54.048800 -54.132408
# 2       265.219353  265.229547  265.129964 -54.094112 -54.048800 -54.086144
# 3       265.219353  265.229547  265.130323 -54.094112 -54.048800 -54.112466
# 4       265.220460  265.229547  265.219353 -54.054388 -54.048800 -54.094112
# ...            ...         ...         ...        ...        ...        ...
# 392079  265.184420  265.196220  265.156256 -54.049368 -54.044034 -54.146548
# 392080  265.139933  265.184420  265.125547 -54.064231 -54.049368 -54.132446
# 392081  265.125547  265.156256  265.139933 -54.132446 -54.146548 -54.064231
# 392082  265.125547  265.156256  265.184420 -54.132446 -54.146548 -54.049368
# 392083  265.139933  265.184420  265.156256 -54.064231 -54.049368 -54.146548
#
#           side_1    side_2    side_3
# 0       0.087098  0.083971  0.045705
# 1       0.111705  0.078097  0.045705
# 2       0.069351  0.053030  0.045705
# 3       0.086266  0.055334  0.045705
# 4       0.045705  0.039729  0.007726
# ...          ...       ...       ...
# 392079  0.105159  0.098572  0.008744
# 392080  0.089967  0.068735  0.030047
# 392081  0.082871  0.068735  0.022858
# 392082  0.098572  0.089967  0.022858
# 392083  0.098572  0.082871  0.030047
#
# [392084 rows x 9 columns]

# %% [markdown]
# ### 三角匹配

# %%
# 筛选，像素坐标转到理想坐标
sext_out_filter.sort(keys=["FLUX_AUTO"], reverse=True)
sext_cat = pd.DataFrame({"XWIN_IMAGE": sext_out_filter["XWIN_IMAGE"], "YWIN_IMAGE": sext_out_filter["YWIN_IMAGE"]})
sext_cat_x = sext_cat["XWIN_IMAGE"]
sext_cat_y = sext_cat["YWIN_IMAGE"]
sex_select_num = 40

x_comb = np.array(list(itertools.combinations(sext_cat_x[:sex_select_num],3)))
y_comb = np.array(list(itertools.combinations(sext_cat_y[:sex_select_num],3)))

x_index_comb = np.array(list(itertools.combinations(sext_cat_x[:sex_select_num].index,3)))
y_index_comb = np.array(list(itertools.combinations(sext_cat_y[:sex_select_num].index,3)))

sext_lib = np.zeros((len(x_comb), 6))
for i in range(3):
    
    xi_sext_out = (CD1_1 * (x_comb[:, i] - x_ref) + CD1_2 * (y_comb[:, i] - y_ref)) * np.pi / 180
    eta_sext_out = (CD2_1 * (x_comb[:, i] - x_ref) + CD2_2 * (y_comb[:, i] - y_ref)) * np.pi / 180

    ra_sext_out, dec_sext_out = ideal_cel_coord(xi_sext_out, eta_sext_out, pointing_ra, pointing_dec)
    sext_lib[:,i] = ra_sext_out
    sext_lib[:,i + 3] = dec_sext_out


for i, comb in enumerate(list(itertools.combinations([2, 1, 0], 2))):
    sext_lib = np.column_stack((sext_lib, pos_side(sext_lib[:, comb[0]], sext_lib[:, comb[0] + 3], sext_lib[:, comb[1]], sext_lib[:, comb[1] + 3])))

sext_lib = np.column_stack((sext_lib, x_index_comb, y_index_comb))

for i in range(len(sext_lib)):
    temp_lib = sext_lib[i, :]
    temp_lib_side = temp_lib[6:9]
    index_max = temp_lib_side == max(temp_lib_side)
    index_min = temp_lib_side == min(temp_lib_side)
    index_mid = ~(index_max | index_min)
    sext_lib[i, :] = (temp_lib.reshape(5, 3) @ np.array([index_max, index_mid, index_min]).T).reshape(15)


sext_lib = pd.DataFrame(sext_lib, columns=['ra_1', 'ra_2', 'ra_3', 'dec_1', 'dec_2', 'dec_3', 'side_1', 'side_2', 'side_3', 'x_1', 'x_2', 'x_3', 'y_1', 'y_2', 'y_3'])

# %%
sext_lib
# Out:
#             ra_1        ra_2        ra_3      dec_1      dec_2      dec_3  \
# 0     265.129737  265.229440  265.262997 -54.101925 -54.048012 -54.141777
# 1     265.129737  265.093299  265.229440 -54.101925 -54.155183 -54.048012
# 2     265.129737  265.119129  265.229440 -54.101925 -54.147760 -54.048012
# 3     265.245537  265.229440  265.129737 -54.063922 -54.048012 -54.101925
# 4     265.129737  265.130901  265.229440 -54.101925 -54.118786 -54.048012
# ...          ...         ...         ...        ...        ...        ...
# 9875  265.110367  265.159164  265.164202 -54.121543 -54.155132 -54.081747
# 9876  265.159164  265.272366  265.071367 -54.155132 -54.102689 -54.041350
# 9877  265.164202  265.272366  265.071367 -54.081747 -54.102689 -54.041350
# 9878  265.164202  265.272366  265.159164 -54.081747 -54.102689 -54.155132
# 9879  265.164202  265.071367  265.159164 -54.081747 -54.041350 -54.155132
#
#         side_1    side_2    side_3   x_1   x_2   x_3   y_1   y_2   y_3
# 0     0.095808  0.087679  0.079553   1.0   0.0   2.0   1.0   0.0   2.0
# 1     0.133634  0.079553  0.057379   1.0   3.0   0.0   1.0   3.0   0.0
# 2     0.118887  0.079553  0.046254   1.0   4.0   0.0   1.0   4.0   0.0
# 3     0.079553  0.077837  0.018505   5.0   0.0   1.0   5.0   0.0   1.0
# 4     0.091380  0.079553  0.016875   1.0   6.0   0.0   1.0   6.0   0.0
# ...        ...       ...       ...   ...   ...   ...   ...   ...   ...
# 9875  0.073445  0.050795  0.044107  35.0  38.0  39.0  35.0  38.0  39.0
# 9876  0.132937  0.124888  0.084559  38.0  36.0  37.0  38.0  36.0  37.0
# 9877  0.132937  0.067828  0.066804  39.0  36.0  37.0  39.0  36.0  37.0
# 9878  0.084559  0.073445  0.066804  39.0  36.0  38.0  39.0  36.0  38.0
# 9879  0.124888  0.073445  0.067828  39.0  37.0  38.0  39.0  37.0  38.0
#
# [9880 rows x 15 columns]

# %%
# 具体匹配
refcat_lib
side_threshold = 0.0001
match_lib = []

for i in range(len(sext_lib)):
    temp_lib = sext_lib.loc[i]
    # index = np.sum(np.abs(refcat_lib - temp_lib[:9]) < side_threshold, axis=1) ==9
    index = np.sum(np.abs(refcat_lib.iloc[:, 6:9] - temp_lib[6:9]) < side_threshold, axis=1) ==3
    index_sum = np.sum(index)
    if index_sum >= 1:
        for j in range(index_sum):
            match_lib.append(np.hstack((np.array(temp_lib[:"dec_3"]), np.array(temp_lib["x_1":"y_3"]), np.array(refcat_lib[index].loc[:, :"dec_3"])[j])))

match_lib = pd.DataFrame(np.array(match_lib), columns=['ra_1', 'ra_2', 'ra_3', 'dec_1', 'dec_2', 'dec_3', 'x_1', 'x_2', 'x_3', 'y_1', 'y_2', 'y_3', 'ra_1', 'ra_2', 'ra_3', 'dec_1', 'dec_2', 'dec_3'])
# with open('match_res.pkl', 'wb') as f:
#     pickle.dump(match_res, f)

# with open('match_res.pkl', 'rb') as f:
#     data = pickle.load(f)

match_lib
# Out:
#            ra_1        ra_2        ra_3      dec_1      dec_2      dec_3  \
# 0    265.129737  265.102894  265.229440 -54.101925 -54.117706 -54.048012
# 1    265.229440  265.216525  265.262997 -54.048012 -54.042643 -54.141777
# 2    265.128345  265.119129  265.229440 -54.142037 -54.147760 -54.048012
# 3    265.245537  265.229440  265.261785 -54.063922 -54.048012 -54.101960
# 4    265.218693  265.219247  265.229440 -54.083641 -54.109942 -54.048012
# ..          ...         ...         ...        ...        ...        ...
# 760  265.124086  265.092645  265.159164 -54.043101 -54.043828 -54.155132
# 761  265.124086  265.081434  265.249186 -54.043101 -54.113629 -54.066981
# 762  265.164202  265.124086  265.272366 -54.081747 -54.043101 -54.102689
# 763  265.249186  265.280393  265.128940 -54.066981 -54.054178 -54.063660
# 764  265.081434  265.110367  265.128940 -54.113629 -54.121543 -54.063660
#
#       x_1   x_2   x_3   y_1   y_2   y_3        ra_1        ra_2        ra_3  \
# 0     1.0  16.0   0.0   1.0  16.0   0.0  265.209747  265.244255  265.083313
# 1     0.0  28.0   2.0   0.0  28.0   2.0  265.188113  265.194363  265.245315
# 2     8.0   4.0   0.0   8.0   4.0   0.0  265.089620  265.076920  265.248147
# 3     5.0   0.0  20.0   5.0   0.0  20.0  265.225382  265.257023  265.161229
# 4    10.0   7.0   0.0  10.0   7.0   0.0  265.178971  265.204857  265.148442
# ..    ...   ...   ...   ...   ...   ...         ...         ...         ...
# 760  27.0  29.0  38.0  27.0  29.0  38.0  265.225382  265.257023  265.189848
# 761  27.0  33.0  31.0  27.0  33.0  31.0  265.148442  265.229547  265.248147
# 762  39.0  27.0  36.0  39.0  27.0  36.0  265.184933  265.246702  265.071100
# 763  31.0  32.0  30.0  31.0  32.0  30.0  265.209747  265.244255  265.155240
# 764  33.0  35.0  30.0  33.0  35.0  30.0  265.267413  265.238515  265.220386
#
#          dec_1      dec_2      dec_3
# 0   -54.052234 -54.042841 -54.080800
# 1   -54.133320 -54.141847 -54.043576
# 2   -54.095954 -54.093514 -54.157123
# 3   -54.153488 -54.152780 -54.141951
# 4   -54.137968 -54.159436 -54.106610
# ..         ...        ...        ...
# 760 -54.153488 -54.152780 -54.041552
# 761 -54.106610 -54.048800 -54.157123
# 762 -54.114331 -54.087334 -54.109808
# 763 -54.052234 -54.042841 -54.115325
# 764 -54.082549 -54.074624 -54.132610
#
# [765 rows x 18 columns]

# %% [markdown]
# ### 结果验证

# %%
match_res = np.array(match_lib)

match_res_ra_sex = match_res[:, 0:3].flatten()
match_res_dec_sex = match_res[:, 3:6].flatten()

match_res_xindex_sex = match_res[:, 6:9].flatten()
match_res_yindex_sex = match_res[:, 9:12].flatten()

match_res_ra_gaia = match_res[:, 12:15].flatten()
match_res_dec_gaia = match_res[:, 15:18].flatten()

# %%
# sext 结果
counts = Counter(match_res_ra_sex)
index_num = np.sort(np.array(list(counts.values())))[-8]
index_num = 100
temp_index = np.array(list(counts.values())) > index_num
match_res_ra_sex_uniqe = list((counts.keys()))
match_res_ra_sex_uniqe = np.array(list(counts.keys()))[temp_index]

counts = Counter(match_res_dec_sex)
match_res_dec_sex_uniqe = list((counts.keys()))
match_res_dec_sex_uniqe = np.array(list(counts.keys()))[temp_index]

counts = Counter(match_res_xindex_sex)
match_res_xindex_sex_uniqe = np.array(list(counts.keys()))[temp_index]

counts = Counter(match_res_yindex_sex)
match_res_yindex_sex_uniqe = np.array(list(counts.keys()))[temp_index]

# gaia 结果
match_res_ra_gaia_uniqe = []
match_res_dec_gaia_uniqe = []
for i, j in zip(match_res_ra_sex_uniqe, match_res_dec_sex_uniqe):
    counts = Counter(match_res_ra_gaia[match_res_ra_sex == i])
    temp_index = np.array(list(counts.values())) == max(list(counts.values()))
    match_res_ra_gaia_uniqe.append(np.array(list(counts.keys()))[temp_index][0])

    counts = Counter(match_res_dec_gaia[match_res_dec_sex == j])
    temp_index = np.array(list(counts.values())) == max(list(counts.values()))
    match_res_dec_gaia_uniqe.append(np.array(list(counts.keys()))[temp_index][0])

match_res_ra_gaia_uniqe = np.array(match_res_ra_gaia_uniqe)
match_res_dec_gaia_uniqe = np.array(match_res_dec_gaia_uniqe)
# counts = Counter(match_res_ra_gaia)
# temp_index = np.array(list(counts.values())) > index_num
# match_res_ra_gaia_uniqe = np.array(list(counts.keys()))[temp_index]

# counts = Counter(match_res_dec_gaia)
# match_res_dec_gaia_uniqe = np.array(list(counts.keys()))[temp_index]

# index = 100
# plt.plot(match_res_ra_sex_uniqe[0:index], match_res_dec_sex_uniqe[0:index], ".")
# plt.plot(match_res_ra_gaia_uniqe[0:index], match_res_dec_gaia_uniqe[0:index], ".")

# print(match_res_ra_sex_uniqe)
# print(match_res_dec_sex_uniqe)
# print(match_res_xindex_sex_uniqe)
# print(match_res_yindex_sex_uniqe)
# print(match_res_ra_gaia_uniqe)
# print(match_res_dec_gaia_uniqe)

# %% [markdown]
# ### 初步底片模型

# %%
# 把匹配到的gaia星转到理想坐标系
match_res_xi_gaia_uniqe, match_res_eta_gaia_uniqe = cel_ideal_coord(match_res_ra_gaia_uniqe, match_res_dec_gaia_uniqe, pointing_ra, pointing_dec)

# 找到匹配图像中匹配的星的像素坐标
match_res_x_sext_uniqe = np.zeros_like(match_res_xi_gaia_uniqe)
match_res_y_sext_uniqe = np.zeros_like(match_res_xi_gaia_uniqe)
for index, i in enumerate(match_res_xindex_sex_uniqe):
    match_res_x_sext_uniqe[index] = sext_cat_x[:sex_select_num].iloc[int(i)]
    match_res_y_sext_uniqe[index] = sext_cat_y[:sex_select_num].iloc[int(i)]

# 底片模型计算
match_x = match_res_x_sext_uniqe
match_y = match_res_y_sext_uniqe
Y_xi = match_res_xi_gaia_uniqe / (np.pi / 180)
Y_eta = match_res_eta_gaia_uniqe / (np.pi / 180)
cof = int(np.floor((np.sqrt(8 * len(match_x) + 1) - 3) / 2))

A_CD_PRE = cal_plate_model(match_x - x_ref, match_y - y_ref, Y_xi, Y_eta, cof)

# 应用
match_xieta = use_plate_model(match_x - x_ref, match_y - y_ref, A_CD_PRE, cof)
# match_xieta = use_plate_model(match_x - x_ref, match_y - y_ref, A_CD)
match_radec = ideal_cel_coord(match_xieta[0], match_xieta[1], pointing_ra, pointing_dec)

print((match_radec[0] - match_res_ra_gaia_uniqe) * 3600000)
print((match_radec[1] - match_res_dec_gaia_uniqe) * 3600000)
# Out:
# [ 43.02168493 -38.82747615  -4.76595383 -23.41372224  34.54818143
#   28.38015928 -27.0449309  -11.89793904]
# [ 2.45419265 -1.82426628  1.42227483 -1.44105719  1.41494274  3.05676025
#  -5.59260207  0.50974733]

# %%
# fig, axes = plt.subplots(1, 3, figsize= (16, 6))

# axes[0].plot(match_radec[0], match_radec[1], '.', c='red')
# axes[1].plot(match_res_ra_gaia_uniqe, match_res_dec_gaia_uniqe, '.', c='blue')

# axes[2].plot(match_radec[0], match_radec[1], '.', c='red')
# axes[2].plot(match_res_ra_gaia_uniqe, match_res_dec_gaia_uniqe, '.', c='blue')

fig, axes = plt.subplots(1, 2, figsize= (16, 6))
from matplotlib.ticker import MaxNLocator
# axes[0].plot(match_radec[0], match_radec[1], '.', c='red')
# axes[1].plot(match_res_ra_gaia_uniqe, match_res_dec_gaia_uniqe, '.', c='blue')

axes[0].plot(match_radec[0], match_radec[1], 'o', c='red', label="stars in image")
axes[0].plot(match_res_ra_gaia_uniqe, match_res_dec_gaia_uniqe, '+', c='blue', label="reference stars")
axes[0].set_ylabel("Dec [degree]")
axes[0].set_xlabel("RA [degree]")
axes[0].xaxis.set_major_locator(MaxNLocator(5))
axes[0].legend(loc=1)


axes[1].hist((match_radec[0] - match_res_ra_gaia_uniqe) * 3600000 * np.mean(np.cos(match_res_dec_gaia_uniqe / 180 * np.pi)), label="RA", bins=10, rwidth=1)
axes[1].hist((match_radec[1] - match_res_dec_gaia_uniqe) * 3600000, label="Dec", bins=10, rwidth=1)
axes[1].set_xlabel(r"$\Delta$ RA / $\Delta$ Dec [mas]")
axes[1].set_ylabel("number")
axes[1].legend(loc=1)

# %% [markdown]
# ### 更新底片模型

# %%
# 全体星应用
sext_flags = sext_out_filter[:]["FLAGS"]
sext_out_x = sext_out_filter[:]["X_IMAGE"][sext_flags == 0]
sext_out_y = sext_out_filter[:]["Y_IMAGE"][sext_flags == 0]
# sext_out_x = sext_out_filter[:]["X_IMAGE"]
# sext_out_y = sext_out_filter[:]["Y_IMAGE"]
sext_out_mag_bp = sext_out_filter[:][f"mag_{band}"][sext_flags == 0]
sext_out_mag_auto = sext_out_filter[:]["MAG_AUTO"][sext_flags == 0]

sext_out_xieta = use_plate_model(sext_out_x - x_ref, sext_out_y - y_ref, A_CD_PRE, cof)
sext_out_radec = ideal_cel_coord(sext_out_xieta[0], sext_out_xieta[1], pointing_ra, pointing_dec)

sext_out_ra = sext_out_radec[0]
sext_out_dec = sext_out_radec[1]

# 全体再次匹配
refcat_lib_all = pd.DataFrame({"RA_ICRS": refcat_ra_now, "DE_ICRS": refcat_dec_now})
side_threshold = 0.0001
match_res_all = []

for i in range(len(sext_out_ra)):
    temp_lib = np.array([sext_out_ra[i], sext_out_dec[i]])
    index = np.sum(np.abs(refcat_lib_all - temp_lib) < side_threshold, axis=1) ==2
    if np.sum(index) == 1:
        match_res_all.append(np.hstack((np.array(temp_lib), int(i), np.array(refcat_lib_all[index].loc[:, :"DE_ICRS"])[0])))

match_res_all = np.array(match_res_all)

# 更新底片模型及
match_res_xi_gaia_all, match_res_eta_gaia_all = cel_ideal_coord(match_res_all[:, 3], match_res_all[:, 4], pointing_ra, pointing_dec)
Y_xi = match_res_xi_gaia_all / (np.pi / 180)
Y_eta = match_res_eta_gaia_all / (np.pi / 180)

match_res_x_sext_all = np.zeros_like(match_res_xi_gaia_all)
match_res_y_sext_all = np.zeros_like(match_res_xi_gaia_all)
match_res_mag_bp_all = np.zeros_like(match_res_xi_gaia_all)
match_res_mag_auto_all = np.zeros_like(match_res_xi_gaia_all)
for index, i in enumerate(match_res_all[:, 2]):
    match_res_x_sext_all[index] = sext_out_x[int(i)]
    match_res_y_sext_all[index] = sext_out_y[int(i)]
    match_res_mag_bp_all[index] = sext_out_mag_bp[int(i)]
    match_res_mag_auto_all[index] = sext_out_mag_auto[int(i)]

match_x = match_res_x_sext_all
match_y = match_res_y_sext_all
match_mag_bp = match_res_mag_bp_all
match_mag_auto = match_res_mag_auto_all

print("the matched stars", len(match_x))

cof = min(int(np.floor((np.sqrt(8 * len(match_x) + 1) - 3) / 2)), 4)
cof = 4
cof_mag = 4
A_CD = cal_plate_model_mag(match_x - x_ref, match_y - y_ref, match_mag_bp, Y_xi, Y_eta, cof, cof_mag)
# A_CD = cal_plate_model(match_x - x_ref, match_y - y_ref, Y_xi, Y_eta, cof)
# A_CD = cal_plate_model_(match_x - x_ref, match_y - y_ref, match_mag_bp, Y_xi, Y_eta)
print(A_CD)

# 再应用底片模型
match_xieta = use_plate_model_mag(match_x - x_ref, match_y - y_ref, match_mag_bp, A_CD, cof, cof_mag)
# match_xieta = use_plate_model(match_x - x_ref, match_y - y_ref, A_CD, cof)
# match_xieta = use_plate_model_(match_x - x_ref, match_y - y_ref, match_mag_bp, A_CD)
match_radec = ideal_cel_coord(match_xieta[0], match_xieta[1], pointing_ra, pointing_dec)
gaia_radec = (match_res_all[:, 3], match_res_all[:, 4])
gaia_xieta = cel_ideal_coord(gaia_radec[0], gaia_radec[1], pointing_ra, pointing_dec)


# 残差
dis_xi = (match_xieta[0] - gaia_xieta[0])
dis_eta = (match_xieta[1] - gaia_xieta[1])
dis_ra = (match_radec[0] - match_res_all[:, 3]) * 3600000
dis_dec = (match_radec[1] - match_res_all[:, 4]) * 3600000

# plt.plot(match_x, match_y, '.')
print(np.std(dis_ra), np.std(dis_dec), cof)
# Out:
# the matched stars 909
# [[-1.41830280e-04  1.38910485e-05 -5.32815254e-09  7.34995151e-13
#    2.05926777e-11  6.11633841e-14 -7.67561229e-16 -1.33009623e-17
#   -9.52220060e-16  1.91824655e-17  4.33412696e-21  1.25529528e-20
#    2.99082839e-21  2.04337291e-20  1.71808764e-21  1.84327288e-05
#   -8.62368516e-07  1.10030241e-08  9.16702311e-11  1.66441701e-11
#   -2.03836278e-12 -1.09366585e-14 -6.83932024e-15  1.30615534e-14]
#  [-1.74761464e-04  6.52938084e-09 -1.39005595e-05 -1.35431102e-11
#   -5.75825674e-13 -3.73363285e-11  2.96398439e-18  9.36642597e-16
#   -6.91786444e-18  1.13944902e-15 -7.17877512e-21 -4.71316877e-21
#   -9.24559437e-21  2.11961777e-20  8.25502410e-21  4.86018813e-05
#   -4.56716902e-06  1.86262835e-07 -2.79306072e-09  2.07290774e-11
#    3.56935722e-11  1.06095099e-14  4.05217000e-15 -4.95831320e-15]]
# 16.517816739097206 12.879928285191252 4

# %%
match_res_pickle = pd.DataFrame({"X_IMAGE": match_x, "Y_IMAGE": match_y, "DIS_RA": dis_ra, "DIS_DEC": dis_dec, "MAG_BP": match_mag_bp, "MAG_AUTO": match_mag_auto})

with open(f'match_res/match_{band}_{unkonw_index}_res.pkl', 'wb') as f:
    pickle.dump(match_res_pickle, f)

# %% [markdown]
# ### 残差图

# %%
# create bins
bins_num = 1
bins_x = np.linspace(0.5, 9216.5, bins_num + 1)
bins_y = np.linspace(0.5, 9232.5, bins_num + 1)

# bins' centers of all box
bin_centers_x = (bins_x[:-1] + bins_x[1:]) / 2
bin_centers_y = (bins_y[:-1] + bins_y[1:]) / 2
bin_centers = np.transpose([np.tile(bin_centers_x, len(bin_centers_y)), np.repeat(bin_centers_y, len(bin_centers_x))])

# calculate error
distort_sum_bins = np.zeros((bins_num, bins_num))
distort_sum_values_x = np.zeros((bins_num, bins_num))
distort_sum_values_y = np.zeros((bins_num, bins_num))

dis_res_xy = [np.vstack((match_x, match_y, dis_xi, dis_eta))]
[distort_sum_bins, distort_sum_values_x, distort_sum_values_y] = cal_distort_model(dis_res_xy, bins_x, bins_y, bins_num, distort_sum_bins, distort_sum_values_x, distort_sum_values_y)

distort_mean_values_x = np.divide(distort_sum_values_x, distort_sum_bins, out=np.zeros_like(distort_sum_values_x), where=distort_sum_bins != 0)
distort_mean_values_y = np.divide(distort_sum_values_y, distort_sum_bins, out=np.zeros_like(distort_sum_values_y), where=distort_sum_bins != 0)

# %%
# mag-distortion
bins_x_id, bins_y_id = match_box_id(match_x, match_y, bins_x, bins_y)

dict_mag_dis = {}
fig, axes = plt.subplots(bins_num, bins_num, figsize= (bins_num * 5, bins_num * 5))


for i in range(0, bins_num):
    for j in range(0, bins_num):

        # 各个区域画图
        dict_mag_dis.update({str(i)+str(j): []})
        index = (bins_x_id == i) & (bins_y_id == j)
        match_mag_box = match_mag_bp[index]
        match_x_box = match_x[index]
        match_y_box = match_y[index]
        dis_ra_box = dis_ra[index]
        dis_dec_box = dis_dec[index]
        # dis_ra_box, match_mag_ra_box = sigma_filter(dis_ra_box, match_mag_box, 3)
        # dis_dec_box, match_mag_dec_box = sigma_filter(dis_dec_box, match_mag_box, 3)

        # index_ra = (match_mag_ra_box < -5) & (match_mag_ra_box > -14)
        # index_dec = (match_mag_dec_box < -5) & (match_mag_dec_box > -14)

        dis_ra_box, dis_dec_box, match_mag_radec_box, filter = sigma_filter_2(dis_ra_box, dis_dec_box, match_mag_box, 3)
        index_ra_dec = (match_mag_radec_box < 29) & (match_mag_radec_box > 15)

        axe = axes if bins_num == 1 else axes[i][j]
        axe.plot(match_mag_radec_box[index_ra_dec], dis_ra_box[index_ra_dec], '.', c='blue', label="ra")
        axe.plot(match_mag_radec_box[index_ra_dec], dis_dec_box[index_ra_dec], '.', c='red', label="dec")
        axe.set_xlabel(f"{band} mag")
        axe.set_ylabel(r"$\Delta$ ra or $\Delta$ dec")
        axe.legend()

# %%
# fig, axes = plt.subplots(bins_num, bins_num, figsize= (bins_num * 5, bins_num * 5))

# for i in range(0, bins_num):
#     for j in range(0, bins_num):

#         # 各个区域画图
#         dict_mag_dis.update({str(i)+str(j): []})
#         index = (bins_x_id == i) & (bins_y_id == j)
#         match_mag_box = match_mag_auto[index]
#         match_x_box = match_x[index]
#         match_y_box = match_y[index]
#         dis_ra_box = dis_ra[index]
#         dis_dec_box = dis_dec[index]
#         dis_ra_box, match_mag_ra_box = sigma_filter(dis_ra_box, match_mag_box, 3)
#         dis_dec_box, match_mag_dec_box = sigma_filter(dis_dec_box, match_mag_box, 3)

#         index_ra = match_mag_ra_box < -5
#         index_dec = match_mag_dec_box < -5

#         axe = axes if bins_num == 1 else axes[i][j]
#         axe.plot(match_mag_ra_box[index_ra], dis_ra_box[index_ra], '.', c='blue', label="ra")
#         axe.plot(match_mag_dec_box[index_dec], dis_dec_box[index_dec], '.', c='red', label="dec")
#         axe.set_xlabel("mag")
#         axe.set_ylabel(r"$\Delta$ ra or $\Delta$ dec")
#         axe.legend()

# %%
bins_num = 10
bins_x = np.linspace(0.5, 9216.5, bins_num + 1)
bins_y = np.linspace(0.5, 9232.5, bins_num + 1)

# bins' centers of all box
bin_centers_x = (bins_x[:-1] + bins_x[1:]) / 2
bin_centers_y = (bins_y[:-1] + bins_y[1:]) / 2
bin_centers = np.transpose([np.tile(bin_centers_x, len(bin_centers_y)), np.repeat(bin_centers_y, len(bin_centers_x))])

# calculate error
distort_sum_bins = np.zeros((bins_num, bins_num))
distort_sum_values_x = np.zeros((bins_num, bins_num))
distort_sum_values_y = np.zeros((bins_num, bins_num))

# dis_res_xy = [np.vstack((match_x, match_y, dis_ra, dis_dec))]
dis_res_xy = [np.vstack((match_x[filter][index_ra_dec], match_y[filter][index_ra_dec], dis_ra[filter][index_ra_dec], dis_dec[filter][index_ra_dec]))]
[distort_sum_bins, distort_sum_values_x, distort_sum_values_y] = cal_distort_model(dis_res_xy, bins_x, bins_y, bins_num, distort_sum_bins, distort_sum_values_x, distort_sum_values_y)

distort_mean_values_x = np.divide(distort_sum_values_x, distort_sum_bins, out=np.zeros_like(distort_sum_values_x), where=distort_sum_bins != 0)
distort_mean_values_y = np.divide(distort_sum_values_y, distort_sum_bins, out=np.zeros_like(distort_sum_values_y), where=distort_sum_bins != 0)

fig, axes = plt.subplots(1, 1)
quiver_scale = 9216
quiver_show_scale = 0.1
quiver = axes.quiver(bin_centers[:, 0], bin_centers[:, 1], distort_mean_values_x.flatten() / 50, distort_mean_values_y.flatten() / 50, scale=1 / quiver_scale, angles = 'xy', scale_units="xy", headwidth=2, headlength=3, width=0.003)
axes.quiverkey(quiver, 0.8, 1.01, quiver_show_scale, f"{quiver_show_scale} pixels",labelpos='E', coordinates='axes')

# %%
# fig, axes = plt.subplots(bins_num, bins_num, figsize= (bins_num * 4, bins_num * 4))

# for i in range(0, bins_num):
#     for j in range(0, bins_num):
#         axes[i][j].plot(dict_mag_dis[str(i)+str(j)][0], dict_mag_dis[str(i)+str(j)][1], '.')
#         axes[i][j].set_xlabel("mag")
#         axes[i][j].set_ylabel(r"$\sigma$ dec")

# %%
# dict_mag_dis["21"]

# x = dict_mag_dis["21"][0]
# y = dict_mag_dis["21"][1]

# X = np.array([np.ones_like(x), x]).T
# Y = y
# A = np.linalg.inv(X.T @ X) @ X.T @ Y

# plt.plot(dict_mag_dis["21"][0], dict_mag_dis["21"][1], '.')
# plt.plot(dict_mag_dis["21"][0], dict_mag_dis["21"][0] * A[1] + A[0], '.')

# %% [markdown]
# ### test

# %%
# # create bins
# bins_num = 4
# bins_x = np.linspace(0.5, 9216.5, bins_num + 1)
# bins_y = np.linspace(0.5, 9232.5, bins_num + 1)

# # bins' centers of all box
# bin_centers_x = (bins_x[:-1] + bins_x[1:]) / 2
# bin_centers_y = (bins_y[:-1] + bins_y[1:]) / 2
# bin_centers = np.transpose([np.tile(bin_centers_x, len(bin_centers_y)), np.repeat(bin_centers_y, len(bin_centers_x))])

# # calculate distortion error model
# distort_sum_bins = np.zeros((bins_num, bins_num))
# distort_sum_values_x = np.zeros((bins_num, bins_num))
# distort_sum_values_y = np.zeros((bins_num, bins_num))

# dis_res_xy = [np.vstack((match_x, match_y, dis_ra, dis_dec))]
# [distort_sum_bins, distort_sum_values_x, distort_sum_values_y] = cal_distort_model(dis_res_xy, bins_x, bins_y, bins_num, distort_sum_bins, distort_sum_values_x, distort_sum_values_y)

# distort_mean_values_x = np.divide(distort_sum_values_x, distort_sum_bins, out=np.zeros_like(distort_sum_values_x), where=distort_sum_bins != 0)
# distort_mean_values_y = np.divide(distort_sum_values_y, distort_sum_bins, out=np.zeros_like(distort_sum_values_y), where=distort_sum_bins != 0)

# # mag-distortion
# bins_x_id, bins_y_id = match_box_id(match_x, match_y, bins_x, bins_y)

# fig, axes = plt.subplots(bins_num, bins_num, figsize= (bins_num * 4, bins_num * 4))

# for i in range(0, bins_num):
#     for j in range(0, bins_num):
#         index = (bins_x_id == i) & (bins_y_id == j)
#         axes[i][j].plot(match_mag[index] * match_x[index], dis_dec[index], '.')

# ax = plt.matshow(distort_sum_bins)
# plt.colorbar(ax.colorbar, fraction=0.025)

# %%
# fig, axes = plt.subplots(1, 2)
# axes[0].quiver(bin_centers[:, 0], bin_centers[:, 1], distort_mean_values_x.flatten(), distort_mean_values_y.flatten(), scale=1500)

# axes[1].matshow(distort_mean_values_x)

# ax = plt.matshow(distort_mean_values_x)
# plt.colorbar(ax.colorbar, fraction=0.025)
# plt.title("matrix X");
# plt.show()
